# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import pickle
from scipy.stats import randint as sp_randint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
# Out:
# /home/haoyuan/assignment1/.env/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def data():
    print('generating data......')
    # read datasets
    X_train = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

    # Shuffle data
    l = [x for x in range(4209)]
    np.random.shuffle(l)
    X_train = X_train.iloc[l]

    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)

    # process type
    for c in X_train.columns:
        if X_train[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(X_train[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    return X_train, y_train, X_test


def turn():
    boost = xgb.XGBRegressor()
    print('trunning model.....')
    parameters = {'learning_rate': [0.005],
                  'gamma': [0,0.5],
                  'max_depth': [4, 9],
                  'min_child_weight': [1,5],
                  "subsample": [0.6,1],
                  'colsample_bytree': [0.6,1],
                 }
    reg = RandomizedSearchCV(boost, parameters, n_jobs=8, cv=3, verbose = 1)
    reg.fit(X_train, y_train)
    best_parameters, score, _ = max(reg.grid_scores_, key=lambda x: x[1])
    print(score)
    for param_name in sorted(best_parameters.keys()):
        print("%s: %r" % (param_name, best_parameters[param_name]))
    pickle.dump( reg.best_params_, open("bestpara.p", "wb" ))
    return reg.best_params_

# %%
X_train,y_train, X_test = data()
# Out:
# generating data......
# ('Shape X_train:', (4209, 377))
# ('Shape X_test:', (4209, 377))

# %%
ID = 'ID'
TARGET = 'y'
NFOLDS = 4
SEED = 0
NROWS = None
DATA_DIR = "../data"

TRAIN_FILE = "{0}/train.csv".format(DATA_DIR)
TEST_FILE = "{0}/test.csv".format(DATA_DIR)
SUBMISSION_FILE = "{0}/sample_submission.csv".format(DATA_DIR)

x_train = np.array(X_train)
x_test = np.array(X_test)
y_train = np.array(y_train)

SEED = 0
ntrain, D = X_train.shape
ntest, _ = X_test.shape
NFOLDS = 4

kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict(x)
    


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        params = params.copy() # creat a local version of params
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))
    

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf):
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        x_te = x_train[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
def turing_xgb(N):
    best_err = 100000000
    data = []
    for _ in range(N):
        params = {
            'colsample_bytree': np.random.uniform(0.01,1),
            'subsample': np.random.uniform(0.01,1),
            'learning_rate': np.exp(np.random.uniform(np.log(0.001),np.log(0.1))),
            'objective': 'reg:linear',
            'max_depth': int(np.random.uniform(1,10)),
            'num_parallel_tree': int(np.random.uniform(1,3)),
            'min_child_weight': int(np.random.uniform(1,5)),
            'nrounds': int(np.random.uniform(300,800))
        }
        model = XgbWrapper(seed=SEED, params=params)
        oof_train, oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err,oof_train)]

    pickle.dump(data,open("xgb.p",'wb'))    
    
def turing(clf,N,name):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_train, oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err,oof_train)]

    pickle.dump(data,open("{}.p".format(name),'wb'))

# %%
N = 40
turing(RandomForestRegressor,N,'rf')
turing(ExtraTreesRegressor,N,'et')
turing_xgb(N)
# Out:
# (70.013151461103035, 70.013151461103035, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.9916385805583589, 'max_depth': 3})
# (69.547439738923401, 69.547439738923401, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 353, 'random_state': 0, 'max_features': 0.6179312710804534, 'max_depth': 7})
# (69.7431282442829, 69.547439738923401, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 368, 'random_state': 0, 'max_features': 0.24640306367913065, 'max_depth': 5})
# (69.715943497493853, 69.547439738923401, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 99, 'random_state': 0, 'max_features': 0.52913138531626, 'max_depth': 7})
# (76.205398458188796, 69.547439738923401, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 642, 'random_state': 0, 'max_features': 0.5203625392273847, 'max_depth': 2})
# (69.299849499818379, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 76, 'random_state': 0, 'max_features': 0.635601408617527, 'max_depth': 6})
# (72.885538377710887, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 352, 'random_state': 0, 'max_features': 0.05733905841554395, 'max_depth': 9})
# (69.358536608784789, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 101, 'random_state': 0, 'max_features': 0.4451980655261796, 'max_depth': 5})
# (77.007756178899086, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 22, 'random_state': 0, 'max_features': 0.05122061252169126, 'max_depth': 7})
# (70.225256527467025, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 412, 'random_state': 0, 'max_features': 0.9667566239956769, 'max_depth': 9})
# (70.802280282212095, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 340, 'random_state': 0, 'max_features': 0.7032264770095124, 'max_depth': 9})
# (102.738525291499, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 518, 'random_state': 0, 'max_features': 0.2444408729828692, 'max_depth': 1})
# (70.365754481932058, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 192, 'random_state': 0, 'max_features': 0.16010203643018964, 'max_depth': 9})
# (71.325525051540623, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 9, 'random_state': 0, 'max_features': 0.2040148962951465, 'max_depth': 5})
# (69.337986913428438, 69.299849499818379, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 560, 'random_state': 0, 'max_features': 0.8599307123653244, 'max_depth': 5})
# (69.245524627914023, 69.245524627914023, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 866, 'random_state': 0, 'max_features': 0.30046102553579823, 'max_depth': 5})
# (69.361993653854114, 69.245524627914023, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 352, 'random_state': 0, 'max_features': 0.6976019755153614, 'max_depth': 6})
# (69.66718347678092, 69.245524627914023, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 715, 'random_state': 0, 'max_features': 0.7076296855236662, 'max_depth': 7})
# (69.169610821354496, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 657, 'random_state': 0, 'max_features': 0.5996024123517883, 'max_depth': 5})
# (70.282145988958163, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 893, 'random_state': 0, 'max_features': 0.2881360492359029, 'max_depth': 9})
# (101.31046373668109, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 188, 'random_state': 0, 'max_features': 0.6957513187573012, 'max_depth': 1})
# (70.073010219966235, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 45, 'random_state': 0, 'max_features': 0.9228591340062534, 'max_depth': 3})
# (70.275369320932967, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 294, 'random_state': 0, 'max_features': 0.4567290510152153, 'max_depth': 3})
# (80.720193542582223, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 182, 'random_state': 0, 'max_features': 0.26387657900952244, 'max_depth': 2})
# (69.963671080586877, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 644, 'random_state': 0, 'max_features': 0.5831908822845127, 'max_depth': 3})
# (70.702427005390149, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 363, 'random_state': 0, 'max_features': 0.3785517819483592, 'max_depth': 3})
# (76.857122809239172, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 218, 'random_state': 0, 'max_features': 0.4644102785799653, 'max_depth': 2})
# (69.919521053228152, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 330, 'random_state': 0, 'max_features': 0.8595912322690722, 'max_depth': 7})
# (73.032137105005489, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 899, 'random_state': 0, 'max_features': 0.10596222297751716, 'max_depth': 5})
# (100.70318996907491, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 808, 'random_state': 0, 'max_features': 0.30277735240823106, 'max_depth': 1})
# (69.598278840964653, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 611, 'random_state': 0, 'max_features': 0.9269744359602115, 'max_depth': 4})
# (69.314559797382827, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 663, 'random_state': 0, 'max_features': 0.5338394857174803, 'max_depth': 5})
# (71.493345836708144, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 588, 'random_state': 0, 'max_features': 0.14018108260388035, 'max_depth': 5})
# (78.509901255326326, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 69, 'random_state': 0, 'max_features': 0.3838107358067537, 'max_depth': 2})
# (103.12082692381603, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 830, 'random_state': 0, 'max_features': 0.2424857212439249, 'max_depth': 1})
# (69.498187014371339, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 388, 'random_state': 0, 'max_features': 0.30321146240865904, 'max_depth': 7})
# (80.492616632293959, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 701, 'random_state': 0, 'max_features': 0.26821914963362675, 'max_depth': 2})
# (96.04508625407378, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 319, 'random_state': 0, 'max_features': 0.07773067542736646, 'max_depth': 2})
# (69.713131679629527, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 131, 'random_state': 0, 'max_features': 0.6612035975580893, 'max_depth': 7})
# (101.6473922476834, 69.169610821354496, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 364, 'random_state': 0, 'max_features': 0.06177105441097599, 'max_depth': 2})
# (70.062106203557889, 70.062106203557889, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 551, 'random_state': 0, 'max_features': 0.5005645495268587, 'max_depth': 8})
# (71.204532610666433, 70.062106203557889, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 563, 'random_state': 0, 'max_features': 0.10372991546303537, 'max_depth': 8})
# (69.663563446141666, 69.663563446141666, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 423, 'random_state': 0, 'max_features': 0.5726063191218562, 'max_depth': 4})
# (69.456112096467606, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 612, 'random_state': 0, 'max_features': 0.3336829436834414, 'max_depth': 4})
# (94.790877468162151, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 82, 'random_state': 0, 'max_features': 0.10614729548328278, 'max_depth': 2})
# (78.292856272041846, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 458, 'random_state': 0, 'max_features': 0.33198966142989317, 'max_depth': 2})
# (70.128113590418394, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 427, 'random_state': 0, 'max_features': 0.9380714899593658, 'max_depth': 4})
# (80.428584222197273, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 112, 'random_state': 0, 'max_features': 0.28415610474664516, 'max_depth': 2})
# (101.82424013911624, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 790, 'random_state': 0, 'max_features': 0.9361622309578154, 'max_depth': 1})
# (100.06789122161425, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 192, 'random_state': 0, 'max_features': 0.5384631966773563, 'max_depth': 1})
# (70.523319951541495, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 827, 'random_state': 0, 'max_features': 0.4260390044471717, 'max_depth': 9})
# (73.440376487785329, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 380, 'random_state': 0, 'max_features': 0.06831098223190457, 'max_depth': 7})
# (70.074169305822821, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 232, 'random_state': 0, 'max_features': 0.2418915817696935, 'max_depth': 7})
# (70.8253172831146, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 268, 'random_state': 0, 'max_features': 0.1447263389890978, 'max_depth': 9})
# (71.546521224708727, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 156, 'random_state': 0, 'max_features': 0.9717380193275935, 'max_depth': 7})
# (71.183865869990811, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 246, 'random_state': 0, 'max_features': 0.8999937401819627, 'max_depth': 9})
# (74.976656531108716, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 424, 'random_state': 0, 'max_features': 0.6246017534193361, 'max_depth': 2})
# (70.41775635710394, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 376, 'random_state': 0, 'max_features': 0.41657348087907625, 'max_depth': 3})
# (75.844460425387581, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 407, 'random_state': 0, 'max_features': 0.8038078424851443, 'max_depth': 2})
# (70.287714630122252, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 563, 'random_state': 0, 'max_features': 0.6016146086188502, 'max_depth': 7})
# (71.311218652682442, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 233, 'random_state': 0, 'max_features': 0.890871567548801, 'max_depth': 7})
# (71.534260823700606, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 112, 'random_state': 0, 'max_features': 0.7970916859351285, 'max_depth': 9})
# (101.51304300473689, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 863, 'random_state': 0, 'max_features': 0.7073438823757343, 'max_depth': 1})
# (70.105202904354925, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 166, 'random_state': 0, 'max_features': 0.23916934761804123, 'max_depth': 7})
# (70.804014939279298, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 132, 'random_state': 0, 'max_features': 0.6396274856210923, 'max_depth': 9})
# (70.51846666294125, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 111, 'random_state': 0, 'max_features': 0.1953326336844241, 'max_depth': 8})
# (69.973656908932242, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 606, 'random_state': 0, 'max_features': 0.6822189304454401, 'max_depth': 4})
# (70.300827177454948, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 784, 'random_state': 0, 'max_features': 0.7850884150724539, 'max_depth': 5})
# (101.88235068489284, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 269, 'random_state': 0, 'max_features': 0.8006285098175079, 'max_depth': 1})
# (101.89001040840789, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 735, 'random_state': 0, 'max_features': 0.8136758054084717, 'max_depth': 1})
# (69.959631733882816, 69.456112096467606, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 358, 'random_state': 0, 'max_features': 0.6272479800094934, 'max_depth': 3})
# (69.427983779988054, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 438, 'random_state': 0, 'max_features': 0.47611230366461166, 'max_depth': 5})
# (70.142976475685032, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 261, 'random_state': 0, 'max_features': 0.5772709445265232, 'max_depth': 6})
# (70.090592813182511, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 240, 'random_state': 0, 'max_features': 0.9473727504093579, 'max_depth': 6})
# (70.800490865875744, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 273, 'random_state': 0, 'max_features': 0.39093013632001367, 'max_depth': 9})
# (69.761598134496609, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 800, 'random_state': 0, 'max_features': 0.34037634183479715, 'max_depth': 4})
# (70.565486038047041, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 201, 'random_state': 0, 'max_features': 0.31399912236488287, 'max_depth': 9})
# (69.800416138917541, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 370, 'random_state': 0, 'max_features': 0.529665077519161, 'max_depth': 5})
# (74.409543013468806, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.9634236012114505, 'max_depth': 9})
# (69.960454060224038, 69.427983779988054, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 326, 'random_state': 0, 'max_features': 0.3659743040342069, 'max_depth': 6})
# (853.75429213439531, 853.75429213439531, {'num_parallel_tree': 1, 'subsample': 0.36079941612042427, 'seed': 0, 'colsample_bytree': 0.27914208480512437, 'nrounds': 371, 'objective': 'reg:linear', 'learning_rate': 0.0034674077762743036, 'max_depth': 9, 'min_child_weight': 2})
# (76.122840233579396, 76.122840233579396, {'num_parallel_tree': 1, 'subsample': 0.46152583896994964, 'seed': 0, 'colsample_bytree': 0.4076101332323178, 'nrounds': 438, 'objective': 'reg:linear', 'learning_rate': 0.0130477294022458, 'max_depth': 1, 'min_child_weight': 4})
# (2681.5305975327055, 76.122840233579396, {'num_parallel_tree': 1, 'subsample': 0.3014196413572881, 'seed': 0, 'colsample_bytree': 0.11948905029097574, 'nrounds': 496, 'objective': 'reg:linear', 'learning_rate': 0.0013787414558479401, 'max_depth': 4, 'min_child_weight': 3})
# (1591.5427060420891, 76.122840233579396, {'num_parallel_tree': 2, 'subsample': 0.6749488159963368, 'seed': 0, 'colsample_bytree': 0.061615153254433175, 'nrounds': 535, 'objective': 'reg:linear', 'learning_rate': 0.0017920962859133578, 'max_depth': 7, 'min_child_weight': 2})
# (99.349458786268514, 76.122840233579396, {'num_parallel_tree': 1, 'subsample': 0.37983268310938434, 'seed': 0, 'colsample_bytree': 0.0543150430483885, 'nrounds': 608, 'objective': 'reg:linear', 'learning_rate': 0.0054009019522214506, 'max_depth': 9, 'min_child_weight': 1})
# (2059.6212704274135, 76.122840233579396, {'num_parallel_tree': 1, 'subsample': 0.9650880222834809, 'seed': 0, 'colsample_bytree': 0.7209963665210848, 'nrounds': 311, 'objective': 'reg:linear', 'learning_rate': 0.0026169917741395662, 'max_depth': 3, 'min_child_weight': 3})
# (479.54229643366955, 76.122840233579396, {'num_parallel_tree': 2, 'subsample': 0.28110403032260384, 'seed': 0, 'colsample_bytree': 0.8059024362684983, 'nrounds': 317, 'objective': 'reg:linear', 'learning_rate': 0.0050795431402097429, 'max_depth': 3, 'min_child_weight': 3})
# (86.771660468973522, 76.122840233579396, {'num_parallel_tree': 2, 'subsample': 0.11448008366082121, 'seed': 0, 'colsample_bytree': 0.8103635094966328, 'nrounds': 694, 'objective': 'reg:linear', 'learning_rate': 0.073832492659820892, 'max_depth': 5, 'min_child_weight': 4})
# (72.265879044286223, 72.265879044286223, {'num_parallel_tree': 2, 'subsample': 0.30815083586276637, 'seed': 0, 'colsample_bytree': 0.9702836972104875, 'nrounds': 760, 'objective': 'reg:linear', 'learning_rate': 0.011427806289017128, 'max_depth': 5, 'min_child_weight': 1})
# (73.765424366791066, 72.265879044286223, {'num_parallel_tree': 2, 'subsample': 0.3954325846996459, 'seed': 0, 'colsample_bytree': 0.7311810712790673, 'nrounds': 520, 'objective': 'reg:linear', 'learning_rate': 0.019444884378227362, 'max_depth': 8, 'min_child_weight': 4})
# (159.11871499929131, 72.265879044286223, {'num_parallel_tree': 2, 'subsample': 0.08103262060428924, 'seed': 0, 'colsample_bytree': 0.4589774364296161, 'nrounds': 748, 'objective': 'reg:linear', 'learning_rate': 0.0033282495340175955, 'max_depth': 1, 'min_child_weight': 1})
# (2880.5928933992673, 72.265879044286223, {'num_parallel_tree': 2, 'subsample': 0.31417878412811, 'seed': 0, 'colsample_bytree': 0.8792360550009545, 'nrounds': 569, 'objective': 'reg:linear', 'learning_rate': 0.001131446959366353, 'max_depth': 8, 'min_child_weight': 2})
# (71.827669112624122, 71.827669112624122, {'num_parallel_tree': 1, 'subsample': 0.175608880975016, 'seed': 0, 'colsample_bytree': 0.8625841099901059, 'nrounds': 312, 'objective': 'reg:linear', 'learning_rate': 0.015020717861667629, 'max_depth': 6, 'min_child_weight': 4})
# (96.244559610078426, 71.827669112624122, {'num_parallel_tree': 1, 'subsample': 0.03352193093999061, 'seed': 0, 'colsample_bytree': 0.6020127085156515, 'nrounds': 325, 'objective': 'reg:linear', 'learning_rate': 0.066667326604742741, 'max_depth': 9, 'min_child_weight': 1})
# (94.939185834875403, 71.827669112624122, {'num_parallel_tree': 2, 'subsample': 0.02459334050974501, 'seed': 0, 'colsample_bytree': 0.7400114929279215, 'nrounds': 554, 'objective': 'reg:linear', 'learning_rate': 0.0059711852186929365, 'max_depth': 2, 'min_child_weight': 1})
# (569.83287728648247, 71.827669112624122, {'num_parallel_tree': 2, 'subsample': 0.607188567559816, 'seed': 0, 'colsample_bytree': 0.5867848861741806, 'nrounds': 769, 'objective': 'reg:linear', 'learning_rate': 0.0019637939835950762, 'max_depth': 2, 'min_child_weight': 2})
# (2114.5208421171023, 71.827669112624122, {'num_parallel_tree': 1, 'subsample': 0.21511828413819178, 'seed': 0, 'colsample_bytree': 0.18290221690630476, 'nrounds': 520, 'objective': 'reg:linear', 'learning_rate': 0.0015531407733709605, 'max_depth': 3, 'min_child_weight': 1})
# (2206.8697771820771, 71.827669112624122, {'num_parallel_tree': 2, 'subsample': 0.355239872916497, 'seed': 0, 'colsample_bytree': 0.2864327927850837, 'nrounds': 512, 'objective': 'reg:linear', 'learning_rate': 0.0015278469270604289, 'max_depth': 8, 'min_child_weight': 2})
# (72.644965777700619, 71.827669112624122, {'num_parallel_tree': 2, 'subsample': 0.8383094394333599, 'seed': 0, 'colsample_bytree': 0.8193623685369728, 'nrounds': 554, 'objective': 'reg:linear', 'learning_rate': 0.02825979332228663, 'max_depth': 5, 'min_child_weight': 3})
# (83.318554187517933, 71.827669112624122, {'num_parallel_tree': 1, 'subsample': 0.09194563382239934, 'seed': 0, 'colsample_bytree': 0.9802927676640217, 'nrounds': 452, 'objective': 'reg:linear', 'learning_rate': 0.0087002172100543469, 'max_depth': 1, 'min_child_weight': 3})
# (142.31067208628244, 71.827669112624122, {'num_parallel_tree': 2, 'subsample': 0.6751814703358403, 'seed': 0, 'colsample_bytree': 0.35864504316911633, 'nrounds': 601, 'objective': 'reg:linear', 'learning_rate': 0.0041472735834473138, 'max_depth': 2, 'min_child_weight': 2})
# (71.323280365294522, 71.323280365294522, {'num_parallel_tree': 2, 'subsample': 0.48345253414955375, 'seed': 0, 'colsample_bytree': 0.807504912322207, 'nrounds': 511, 'objective': 'reg:linear', 'learning_rate': 0.01118579105402759, 'max_depth': 8, 'min_child_weight': 4})
# (72.222607056099491, 71.323280365294522, {'num_parallel_tree': 2, 'subsample': 0.8536418012598219, 'seed': 0, 'colsample_bytree': 0.3303456344732546, 'nrounds': 659, 'objective': 'reg:linear', 'learning_rate': 0.0123552572178653, 'max_depth': 9, 'min_child_weight': 2})
# (578.08708021381449, 71.323280365294522, {'num_parallel_tree': 2, 'subsample': 0.20889452933458963, 'seed': 0, 'colsample_bytree': 0.22843440237799184, 'nrounds': 696, 'objective': 'reg:linear', 'learning_rate': 0.0021757421460249374, 'max_depth': 2, 'min_child_weight': 4})
# (78.297161339287229, 71.323280365294522, {'num_parallel_tree': 2, 'subsample': 0.19269082713543334, 'seed': 0, 'colsample_bytree': 0.19971625635352744, 'nrounds': 593, 'objective': 'reg:linear', 'learning_rate': 0.099449954865619417, 'max_depth': 3, 'min_child_weight': 2})
# (72.51036939643636, 71.323280365294522, {'num_parallel_tree': 1, 'subsample': 0.11311764041773888, 'seed': 0, 'colsample_bytree': 0.3820366033238633, 'nrounds': 705, 'objective': 'reg:linear', 'learning_rate': 0.0088912341348004898, 'max_depth': 8, 'min_child_weight': 1})
# (143.78621897901112, 71.323280365294522, {'num_parallel_tree': 1, 'subsample': 0.3144048119054477, 'seed': 0, 'colsample_bytree': 0.3936835376140062, 'nrounds': 534, 'objective': 'reg:linear', 'learning_rate': 0.0046472003686355654, 'max_depth': 5, 'min_child_weight': 3})
# (70.21880752428801, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.60070902897291, 'seed': 0, 'colsample_bytree': 0.15552561646089585, 'nrounds': 675, 'objective': 'reg:linear', 'learning_rate': 0.012074774364506815, 'max_depth': 3, 'min_child_weight': 3})
# (282.51051721364036, 70.21880752428801, {'num_parallel_tree': 1, 'subsample': 0.3856436766558836, 'seed': 0, 'colsample_bytree': 0.4885268020749643, 'nrounds': 597, 'objective': 'reg:linear', 'learning_rate': 0.0032548441311580408, 'max_depth': 7, 'min_child_weight': 2})
# (72.433353521097331, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.8943795723790308, 'seed': 0, 'colsample_bytree': 0.5136970848685892, 'nrounds': 373, 'objective': 'reg:linear', 'learning_rate': 0.024259103100597975, 'max_depth': 9, 'min_child_weight': 1})
# (101.81251607449234, 70.21880752428801, {'num_parallel_tree': 1, 'subsample': 0.47000529635630744, 'seed': 0, 'colsample_bytree': 0.9982511259605443, 'nrounds': 576, 'objective': 'reg:linear', 'learning_rate': 0.0050874841854554355, 'max_depth': 9, 'min_child_weight': 1})
# (5181.3973450036037, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.6834348996062254, 'seed': 0, 'colsample_bytree': 0.42369994868990485, 'nrounds': 329, 'objective': 'reg:linear', 'learning_rate': 0.0010415343564855837, 'max_depth': 3, 'min_child_weight': 3})
# (72.049144725079174, 70.21880752428801, {'num_parallel_tree': 1, 'subsample': 0.13232497871697807, 'seed': 0, 'colsample_bytree': 0.5504337085764465, 'nrounds': 661, 'objective': 'reg:linear', 'learning_rate': 0.018947030353781039, 'max_depth': 2, 'min_child_weight': 3})
# (72.519699853417222, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.3779899073321167, 'seed': 0, 'colsample_bytree': 0.4808382505351946, 'nrounds': 418, 'objective': 'reg:linear', 'learning_rate': 0.023594111265557206, 'max_depth': 1, 'min_child_weight': 4})
# (74.472306331400929, 70.21880752428801, {'num_parallel_tree': 1, 'subsample': 0.1672354998875177, 'seed': 0, 'colsample_bytree': 0.663030880670547, 'nrounds': 729, 'objective': 'reg:linear', 'learning_rate': 0.014698079253741789, 'max_depth': 8, 'min_child_weight': 3})
# (72.056148534615829, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.24241337476981048, 'seed': 0, 'colsample_bytree': 0.5020150288514464, 'nrounds': 549, 'objective': 'reg:linear', 'learning_rate': 0.0080589708299474098, 'max_depth': 2, 'min_child_weight': 1})
# (84.86447353714513, 70.21880752428801, {'num_parallel_tree': 1, 'subsample': 0.10786263984112432, 'seed': 0, 'colsample_bytree': 0.5507950247048232, 'nrounds': 620, 'objective': 'reg:linear', 'learning_rate': 0.079586914288398328, 'max_depth': 3, 'min_child_weight': 2})
# (70.97158291894101, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.7588204188747456, 'seed': 0, 'colsample_bytree': 0.9654517233756656, 'nrounds': 664, 'objective': 'reg:linear', 'learning_rate': 0.012086259966694697, 'max_depth': 6, 'min_child_weight': 1})
# (84.208550559988254, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.12431706347243568, 'seed': 0, 'colsample_bytree': 0.14879025963967987, 'nrounds': 399, 'objective': 'reg:linear', 'learning_rate': 0.091749512104732159, 'max_depth': 9, 'min_child_weight': 2})
# (82.53910492749246, 70.21880752428801, {'num_parallel_tree': 2, 'subsample': 0.6471205231356666, 'seed': 0, 'colsample_bytree': 0.9345311047158825, 'nrounds': 494, 'objective': 'reg:linear', 'learning_rate': 0.095890639685204448, 'max_depth': 8, 'min_child_weight': 1})

# %%
len(pickle.load(open('et.p')))
# Out:
# 40
