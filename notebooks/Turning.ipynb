# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import pickle
from scipy.stats import randint as sp_randint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
# Out:
# /home/haoyuan/assignment1/.env/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def data():
    print('generating data......')
    # read datasets
    X_train = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

    # Shuffle data
    l = [x for x in range(4209)]
    np.random.shuffle(l)
    X_train = X_train.iloc[l]

    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)

    # process type
    for c in X_train.columns:
        if X_train[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(X_train[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    return X_train, y_train, X_test


def turn():
    boost = xgb.XGBRegressor()
    print('trunning model.....')
    parameters = {'learning_rate': [0.005],
                  'gamma': [0,0.5],
                  'max_depth': [4, 9],
                  'min_child_weight': [1,5],
                  "subsample": [0.6,1],
                  'colsample_bytree': [0.6,1],
                 }
    reg = RandomizedSearchCV(boost, parameters, n_jobs=8, cv=3, verbose = 1)
    reg.fit(X_train, y_train)
    best_parameters, score, _ = max(reg.grid_scores_, key=lambda x: x[1])
    print(score)
    for param_name in sorted(best_parameters.keys()):
        print("%s: %r" % (param_name, best_parameters[param_name]))
    pickle.dump( reg.best_params_, open("bestpara.p", "wb" ))
    return reg.best_params_

# %%
X_train,y_train, X_test = data()
# Out:
# generating data......
# ('Shape X_train:', (4209, 377))
# ('Shape X_test:', (4209, 377))

# %%
ID = 'ID'
TARGET = 'y'
NFOLDS = 4
SEED = 0
NROWS = None
DATA_DIR = "../data"

TRAIN_FILE = "{0}/train.csv".format(DATA_DIR)
TEST_FILE = "{0}/test.csv".format(DATA_DIR)
SUBMISSION_FILE = "{0}/sample_submission.csv".format(DATA_DIR)

x_train = np.array(X_train)
x_test = np.array(X_test)
y_train = np.array(y_train)

SEED = 0
ntrain, D = X_train.shape
ntest, _ = X_test.shape
NFOLDS = 4

kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict(x)
    


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))
    

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf):
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        x_te = x_train[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
def turing_xgb(N):
    best_err = 100000000
    data = []
    for _ in range(N):
        params = {
            'colsample_bytree': np.random.uniform(0,1),
            'subsample': np.random.uniform(0,1),
            'learning_rate': np.exp(np.random.uniform(np.log(0.001),np.log(0.1))),
            'objective': 'reg:linear',
            'max_depth': int(np.random.uniform(1,10)),
            'num_parallel_tree': int(np.random.uniform(1,3)),
            'min_child_weight': int(np.random.uniform(1,5)),
            'nrounds': int(np.random.uniform(300,600))
        }
        model = XgbWrapper(seed=SEED, params=params)
        oof_train, oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err)]

    pickle.dump(data,open("xgb.p",'wb'))    
    
def turing(clf,N,name):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(0,900))
        max_features = np.random.uniform(0,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 16,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_train, oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err)]

    pickle.dump(data,open("{}.p".format(name),'wb'))

# %%
N = 30
turing(RandomForestRegressor,N,'rf')
turing(ExtraTreesRegressor,N,'et')
turing_xgb(N)
# Out:
# (70.225143972268995, 70.225143972268995, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 296, 'random_state': 0, 'max_features': 0.8488982276297887, 'max_depth': 6})
# (69.223489804167713, 69.223489804167713, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 610, 'random_state': 0, 'max_features': 0.7088845691569939, 'max_depth': 4})
# (70.319305042553282, 69.223489804167713, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 437, 'random_state': 0, 'max_features': 0.7735681785891426, 'max_depth': 9})
# (69.593332535725963, 69.223489804167713, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 408, 'random_state': 0, 'max_features': 0.30713390426611253, 'max_depth': 7})
# (69.938280809994993, 69.223489804167713, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 850, 'random_state': 0, 'max_features': 0.2518702917484106, 'max_depth': 8})
# (69.366392314132412, 69.223489804167713, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 161, 'random_state': 0, 'max_features': 0.4995727193540054, 'max_depth': 6})
# (69.133030074761066, 69.133030074761066, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 314, 'random_state': 0, 'max_features': 0.7279852842973413, 'max_depth': 5})
# (75.160424033953561, 69.133030074761066, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 506, 'random_state': 0, 'max_features': 0.6406485082619162, 'max_depth': 2})
# (69.167377603874101, 69.133030074761066, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 206, 'random_state': 0, 'max_features': 0.7911323650327456, 'max_depth': 4})
# (96.684885934651973, 69.133030074761066, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 517, 'random_state': 0, 'max_features': 0.0814096193953644, 'max_depth': 2})
# (69.306580346469488, 69.133030074761066, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 155, 'random_state': 0, 'max_features': 0.7326831126468017, 'max_depth': 4})
# (69.090853048104464, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 563, 'random_state': 0, 'max_features': 0.7418796609738209, 'max_depth': 5})
# (71.329518400637454, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 122, 'random_state': 0, 'max_features': 0.46099256302440017, 'max_depth': 9})
# (69.959090048678917, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 443, 'random_state': 0, 'max_features': 0.2757169441243974, 'max_depth': 8})
# (69.76949810166046, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 348, 'random_state': 0, 'max_features': 0.8659817891104036, 'max_depth': 7})
# (70.467844122498093, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 34, 'random_state': 0, 'max_features': 0.4025317549957863, 'max_depth': 3})
# (69.103102682127272, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 656, 'random_state': 0, 'max_features': 0.7520685725191586, 'max_depth': 5})
# (70.748771683351947, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 606, 'random_state': 0, 'max_features': 0.8168815368159696, 'max_depth': 9})
# (69.235580350445375, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 847, 'random_state': 0, 'max_features': 0.6480717876914137, 'max_depth': 4})
# (69.541654098971335, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 246, 'random_state': 0, 'max_features': 0.7411992804890523, 'max_depth': 7})
# (69.437860383753744, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 285, 'random_state': 0, 'max_features': 0.42607408380268674, 'max_depth': 6})
# (73.48432868146746, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 2, 'random_state': 0, 'max_features': 0.2413030573001701, 'max_depth': 5})
# (69.361680981649528, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 97, 'random_state': 0, 'max_features': 0.4994603101615739, 'max_depth': 6})
# (69.303531611241368, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 753, 'random_state': 0, 'max_features': 0.789360394195695, 'max_depth': 6})
# (81.773872833720873, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 767, 'random_state': 0, 'max_features': 0.23493379058856423, 'max_depth': 2})
# (70.505166939647623, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 291, 'random_state': 0, 'max_features': 0.3932195826648335, 'max_depth': 3})
# (99.562387737996076, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 157, 'random_state': 0, 'max_features': 0.46272312189237264, 'max_depth': 1})
# (76.568567998057219, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 377, 'random_state': 0, 'max_features': 0.15841351550817395, 'max_depth': 3})
# (70.123398083453367, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 612, 'random_state': 0, 'max_features': 0.9534370187471654, 'max_depth': 8})
# (69.37451948854924, 69.090853048104464, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 370, 'random_state': 0, 'max_features': 0.4602894256245128, 'max_depth': 6})
# (77.468081617119296, 77.468081617119296, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 722, 'random_state': 0, 'max_features': 0.7402223212473804, 'max_depth': 2})
# (69.777643758309864, 69.777643758309864, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 755, 'random_state': 0, 'max_features': 0.5875470198460481, 'max_depth': 3})
# (69.328518033073479, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 439, 'random_state': 0, 'max_features': 0.5744763391667906, 'max_depth': 4})
# (71.494734591323819, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 673, 'random_state': 0, 'max_features': 0.08159816755517735, 'max_depth': 9})
# (70.007378185631111, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 42, 'random_state': 0, 'max_features': 0.18541917648521633, 'max_depth': 6})
# (69.546917200221444, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 542, 'random_state': 0, 'max_features': 0.7474818358569026, 'max_depth': 4})
# (69.634109608658704, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 787, 'random_state': 0, 'max_features': 0.9097510857354256, 'max_depth': 5})
# (76.192246487018309, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 783, 'random_state': 0, 'max_features': 0.49156588489057373, 'max_depth': 2})
# (69.440620121734582, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 876, 'random_state': 0, 'max_features': 0.4388079787642055, 'max_depth': 5})
# (71.124356391131982, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 380, 'random_state': 0, 'max_features': 0.323720170343497, 'max_depth': 3})
# (70.266693747317902, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 818, 'random_state': 0, 'max_features': 0.2345881896503803, 'max_depth': 8})
# (80.438214346534338, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 646, 'random_state': 0, 'max_features': 0.10938874051970027, 'max_depth': 3})
# (103.46453054229043, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 7, 'random_state': 0, 'max_features': 0.8073001399679841, 'max_depth': 1})
# (69.410022496312195, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 832, 'random_state': 0, 'max_features': 0.3267859353188942, 'max_depth': 4})
# (75.840592564232409, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 23, 'random_state': 0, 'max_features': 0.10300887509526946, 'max_depth': 4})
# (70.11931323660707, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 3, 'n_estimators': 135, 'random_state': 0, 'max_features': 0.5252351819850521, 'max_depth': 7})
# (73.11538202917157, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 93, 'random_state': 0, 'max_features': 0.15933833194995362, 'max_depth': 4})
# (100.08514146657112, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 230, 'random_state': 0, 'max_features': 0.5037975113598008, 'max_depth': 1})
# (122.26309885587793, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 266, 'random_state': 0, 'max_features': 0.07295573769685137, 'max_depth': 1})
# (101.7809322910834, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 476, 'random_state': 0, 'max_features': 0.775777337479979, 'max_depth': 1})
# (71.275634345683258, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 210, 'random_state': 0, 'max_features': 0.2972066121012493, 'max_depth': 3})
# (69.725220357099914, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 603, 'random_state': 0, 'max_features': 0.48632913587737925, 'max_depth': 6})
# (70.843654437415196, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 345, 'random_state': 0, 'max_features': 0.7594889949096537, 'max_depth': 7})
# (72.030447491144244, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 605, 'random_state': 0, 'max_features': 0.8441383418686984, 'max_depth': 9})
# (69.348210571123673, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 2, 'n_estimators': 137, 'random_state': 0, 'max_features': 0.5503296398374032, 'max_depth': 4})
# (70.123238717460438, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 5, 'n_estimators': 280, 'random_state': 0, 'max_features': 0.6726063682234709, 'max_depth': 7})
# (111.99217619979419, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 4, 'n_estimators': 899, 'random_state': 0, 'max_features': 0.1303105300554337, 'max_depth': 1})
# (77.387636786368844, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 896, 'random_state': 0, 'max_features': 0.7337533092666356, 'max_depth': 2})
# (101.85034798529252, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 6, 'n_estimators': 389, 'random_state': 0, 'max_features': 0.8093269054663663, 'max_depth': 1})
# (74.11254851102899, 69.328518033073479, {'n_jobs': 16, 'min_samples_leaf': 1, 'n_estimators': 436, 'random_state': 0, 'max_features': 0.19225051574427898, 'max_depth': 3})
# (115.10289158806368, 115.10289158806368, {'num_parallel_tree': 1, 'subsample': 0.9808047925830181, 'seed': 0, 'colsample_bytree': 0.8701949902689516, 'objective': 'reg:linear', 'learning_rate': 0.0084926280351230107, 'max_depth': 1, 'min_child_weight': 1})
# (84.300539809876824, 84.300539809876824, {'num_parallel_tree': 1, 'subsample': 0.5412272137134861, 'seed': 0, 'colsample_bytree': 0.6230758779133788, 'objective': 'reg:linear', 'learning_rate': 0.070845130278070115, 'max_depth': 8, 'min_child_weight': 3})
# (69.827435382096255, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.49536164958414597, 'seed': 0, 'colsample_bytree': 0.6319525085254464, 'objective': 'reg:linear', 'learning_rate': 0.014523962637987964, 'max_depth': 5, 'min_child_weight': 1})
# (2762.4534531905156, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.010685316633928243, 'seed': 0, 'colsample_bytree': 0.721694676256004, 'objective': 'reg:linear', 'learning_rate': 0.0016295090308059829, 'max_depth': 2, 'min_child_weight': 4})
# (79.320434304381962, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.022630902219518023, 'seed': 0, 'colsample_bytree': 0.9487731859189176, 'objective': 'reg:linear', 'learning_rate': 0.038984837148170373, 'max_depth': 1, 'min_child_weight': 2})
# (2880.5676175070616, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.15943927785695178, 'seed': 0, 'colsample_bytree': 0.49037972785039385, 'objective': 'reg:linear', 'learning_rate': 0.0016310858386506188, 'max_depth': 5, 'min_child_weight': 4})
# (79.576168580503065, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.6689973608315258, 'seed': 0, 'colsample_bytree': 0.8963443729984981, 'objective': 'reg:linear', 'learning_rate': 0.057580570129266546, 'max_depth': 7, 'min_child_weight': 4})
# (4456.5035582171513, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.8050576459009245, 'seed': 0, 'colsample_bytree': 0.12808571914937705, 'objective': 'reg:linear', 'learning_rate': 0.0012442066532560138, 'max_depth': 4, 'min_child_weight': 2})
# (75.407823647054656, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.8037826270869415, 'seed': 0, 'colsample_bytree': 0.6564916371969577, 'objective': 'reg:linear', 'learning_rate': 0.084965102135376003, 'max_depth': 5, 'min_child_weight': 1})
# (1707.8141081871017, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.1083226165319624, 'seed': 0, 'colsample_bytree': 0.3907683128517626, 'objective': 'reg:linear', 'learning_rate': 0.002496416481621121, 'max_depth': 2, 'min_child_weight': 1})
# (80.024274235550877, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.32244127316722926, 'seed': 0, 'colsample_bytree': 0.43273645629086976, 'objective': 'reg:linear', 'learning_rate': 0.04029753144768667, 'max_depth': 8, 'min_child_weight': 3})
# (126.44149541432904, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.054711379498418644, 'seed': 0, 'colsample_bytree': 0.10796003194207937, 'objective': 'reg:linear', 'learning_rate': 0.0073791296955895867, 'max_depth': 2, 'min_child_weight': 2})
# (71.824351522616382, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.5732096525125191, 'seed': 0, 'colsample_bytree': 0.6521096416364041, 'objective': 'reg:linear', 'learning_rate': 0.078915360720389877, 'max_depth': 2, 'min_child_weight': 1})
# (358.71408135098022, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.7314379965968246, 'seed': 0, 'colsample_bytree': 0.7478253994375861, 'objective': 'reg:linear', 'learning_rate': 0.0057192657233808746, 'max_depth': 9, 'min_child_weight': 4})
# (79.669060849329171, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.5242732158157526, 'seed': 0, 'colsample_bytree': 0.5099547317672127, 'objective': 'reg:linear', 'learning_rate': 0.046563731396196378, 'max_depth': 8, 'min_child_weight': 3})
# (189.40310448104978, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.7776995356886749, 'seed': 0, 'colsample_bytree': 0.38667621690998244, 'objective': 'reg:linear', 'learning_rate': 0.0037799631368465145, 'max_depth': 2, 'min_child_weight': 1})
# (75.946038692217726, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.5933368104334259, 'seed': 0, 'colsample_bytree': 0.6875606635599021, 'objective': 'reg:linear', 'learning_rate': 0.010849274465510423, 'max_depth': 1, 'min_child_weight': 4})
# (71.928255612892556, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.42101341434012907, 'seed': 0, 'colsample_bytree': 0.1947588873843653, 'objective': 'reg:linear', 'learning_rate': 0.016570932636712089, 'max_depth': 6, 'min_child_weight': 3})
# (76.085914193148426, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.3705261078141622, 'seed': 0, 'colsample_bytree': 0.3845517195306607, 'objective': 'reg:linear', 'learning_rate': 0.033014912409077862, 'max_depth': 9, 'min_child_weight': 4})
# (1438.6654348982559, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.08283924283928501, 'seed': 0, 'colsample_bytree': 0.7013160464130284, 'objective': 'reg:linear', 'learning_rate': 0.0027686111704289832, 'max_depth': 5, 'min_child_weight': 1})
# (520.81829943866796, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.20658618507625548, 'seed': 0, 'colsample_bytree': 0.8317774903899124, 'objective': 'reg:linear', 'learning_rate': 0.0031099419048152828, 'max_depth': 2, 'min_child_weight': 4})
# (2361.9325810638984, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.9618282857429297, 'seed': 0, 'colsample_bytree': 0.6727813895598844, 'objective': 'reg:linear', 'learning_rate': 0.0020848272059787129, 'max_depth': 2, 'min_child_weight': 3})
# (2554.1959277649203, 69.827435382096255, {'num_parallel_tree': 1, 'subsample': 0.9763481379794962, 'seed': 0, 'colsample_bytree': 0.10596014107042018, 'objective': 'reg:linear', 'learning_rate': 0.0015577846621794764, 'max_depth': 5, 'min_child_weight': 3})
# (76.170347860351853, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.40304074319834904, 'seed': 0, 'colsample_bytree': 0.9655428140790564, 'objective': 'reg:linear', 'learning_rate': 0.038135749660846402, 'max_depth': 5, 'min_child_weight': 3})
# (70.914612931499605, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.9755300650534175, 'seed': 0, 'colsample_bytree': 0.9047207290510134, 'objective': 'reg:linear', 'learning_rate': 0.045963361238346642, 'max_depth': 3, 'min_child_weight': 4})
# (72.034658710718304, 69.827435382096255, {'num_parallel_tree': 2, 'subsample': 0.394948858840254, 'seed': 0, 'colsample_bytree': 0.4398068196708411, 'objective': 'reg:linear', 'learning_rate': 0.027124887712759945, 'max_depth': 5, 'min_child_weight': 2})
# (69.227751460855629, 69.227751460855629, {'num_parallel_tree': 1, 'subsample': 0.6643919355993264, 'seed': 0, 'colsample_bytree': 0.4869762905620898, 'objective': 'reg:linear', 'learning_rate': 0.021900406672619669, 'max_depth': 2, 'min_child_weight': 2})
# (365.26911624438566, 69.227751460855629, {'num_parallel_tree': 1, 'subsample': 0.2968829207964786, 'seed': 0, 'colsample_bytree': 0.7217805705111853, 'objective': 'reg:linear', 'learning_rate': 0.0035140924239827763, 'max_depth': 8, 'min_child_weight': 1})
# (3574.0413223999531, 69.227751460855629, {'num_parallel_tree': 2, 'subsample': 0.770652791367491, 'seed': 0, 'colsample_bytree': 0.6062970446010938, 'objective': 'reg:linear', 'learning_rate': 0.0017029105252902967, 'max_depth': 9, 'min_child_weight': 1})
# (465.39891724159952, 69.227751460855629, {'num_parallel_tree': 1, 'subsample': 0.024051744321267998, 'seed': 0, 'colsample_bytree': 0.031409775952889074, 'objective': 'reg:linear', 'learning_rate': 0.0046868236915442963, 'max_depth': 4, 'min_child_weight': 2})
