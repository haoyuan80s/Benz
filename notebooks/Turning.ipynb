# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import pickle
from scipy.stats import randint as sp_randint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor

# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

# %%
def data_with_val():
    print('generating data......')
    # read datasets
    train_total = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

    # Shuffle data
    np.random.seed(0)
    l = [x for x in range(4209)]
    np.random.shuffle(l)
    train_total = train_total.iloc[l]

    # split data
    ratio = 0.8
    threshold = int(ratio*4209)
    X_train = train_total.iloc[range(threshold)] 
    val = train_total.iloc[range(threshold, 4209)]
    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)
    y_val = val['y']
    X_val = val.drop('y', axis = 1)

    # process type
    for c in train_total.columns:
        if train_total[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(train_total[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_val[c] = lbl.transform(list(X_val[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    print('Shape X_val:', X_val.shape )
    return X_train, y_train, X_val, y_val, X_test

def data():
    print('generating data......')
    # read datasets
    X_train = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

#     # Shuffle data
#     l = [x for x in range(4209)]
#     np.random.seed(0)
#     np.random.shuffle(l)
#     X_train = X_train.iloc[l]

    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)

    # process type
    for c in X_train.columns:
        if X_train[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(X_train[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    return X_train, y_train, X_test

# %%
X_train,y_train, X_val,y_val, X_test = data_with_val()
# Out:
# generating data......
# ('Shape X_train:', (3367, 377))
# ('Shape X_test:', (4209, 377))
# ('Shape X_val:', (842, 377))

# %%
# Gloable data

ID = 'ID'
TARGET = 'y'
NFOLDS = 4
SEED = 1
NROWS = None
DATA_DIR = "../data"
SUBMISSION_FILE = "{0}/sample_submission.csv".format(DATA_DIR)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)

SEED = 0
ntrain, D = X_train.shape
nval = X_val.shape[0]
ntest = X_test.shape[0]
NFOLDS = 4

kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, X_train, y_train):
        self.clf.fit(X_train, y_train)

    def predict(self, X):
        return self.clf.predict(X)
    

class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        params = params.copy() # creat a local version of params
        self.nrounds = params.pop('nrounds', 250)

    def train(self, X_train, y_train):
        dtrain = xgb.DMatrix(X_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, X):
        return self.gbdt.predict(xgb.DMatrix(X))
    

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))

    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]

        clf.train(X_tr, y_tr)

        oof_train[test_index] = clf.predict(X_te)
        oof_test_skf[i, :] = clf.predict(X_test)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_test[:] = oof_test_skf.mean(axis=0)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
def turing_xgb(N):
    best_err = 100000000
    data = []
    for _ in range(N):
        params = {
            'colsample_bytree': np.random.uniform(0.01,1),
            'subsample': np.random.uniform(0.01,1),
            'learning_rate': np.exp(np.random.uniform(np.log(0.001),np.log(0.1))),
            'objective': 'reg:linear',
            'max_depth': int(np.random.uniform(1,10)),
            'num_parallel_tree': int(np.random.uniform(1,3)),
            'min_child_weight': int(np.random.uniform(1,5)),
            'nrounds': int(np.random.uniform(300,800))
        }
        model = XgbWrapper(seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err, oof_train, oof_val, oof_test)]

    pickle.dump(data,open("xgb.p",'wb'))    
    
def turing(clf,N,name):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err,oof_train, oof_val, oof_test)]

    pickle.dump(data,open("{}.p".format(name),'wb'))

# %%
N = 40
turing(RandomForestRegressor,N,'rf')
turing(ExtraTreesRegressor,N,'et')
turing_xgb(N)
# Out:
# (96.323827329174392, 96.323827329174392, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 286, 'random_state': 0, 'max_features': 0.024499432235574173, 'max_depth': 5})
# (71.538100058774646, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 811, 'random_state': 0, 'max_features': 0.7649142272517786, 'max_depth': 5})
# (74.295057343719435, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 502, 'random_state': 0, 'max_features': 0.8861720323891933, 'max_depth': 8})
# (73.19264882492584, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 606, 'random_state': 0, 'max_features': 0.16160041019820734, 'max_depth': 8})
# (71.798195078706158, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 777, 'random_state': 0, 'max_features': 0.2976875139014636, 'max_depth': 6})
# (71.655011596246226, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 877, 'random_state': 0, 'max_features': 0.4153271175045414, 'max_depth': 5})
# (120.64692631000788, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 572, 'random_state': 0, 'max_features': 0.0873765381289197, 'max_depth': 1})
# (71.81240519028141, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 166, 'random_state': 0, 'max_features': 0.408680141828105, 'max_depth': 4})
# (104.54539525131128, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 691, 'random_state': 0, 'max_features': 0.8460364875625905, 'max_depth': 1})
# (77.269974531365079, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 17, 'random_state': 0, 'max_features': 0.14467786838552604, 'max_depth': 4})
# (104.52215489481767, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 432, 'random_state': 0, 'max_features': 0.9726737152291963, 'max_depth': 1})
# (72.495026283165501, 71.538100058774646, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 161, 'random_state': 0, 'max_features': 0.4335969539846919, 'max_depth': 7})
# (71.380426698719816, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 75, 'random_state': 0, 'max_features': 0.7667115870795428, 'max_depth': 4})
# (72.459939680071898, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 418, 'random_state': 0, 'max_features': 0.6903673404124713, 'max_depth': 7})
# (77.106650086455232, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 786, 'random_state': 0, 'max_features': 0.6129454437053583, 'max_depth': 2})
# (104.5242144815914, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.9940295709516269, 'max_depth': 1})
# (73.030590631831188, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 607, 'random_state': 0, 'max_features': 0.26333657849004677, 'max_depth': 8})
# (72.899680990436721, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 527, 'random_state': 0, 'max_features': 0.8143066365736331, 'max_depth': 8})
# (71.918248726698522, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 873, 'random_state': 0, 'max_features': 0.7387646171979815, 'max_depth': 6})
# (73.177871769038575, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 211, 'random_state': 0, 'max_features': 0.39805053080537056, 'max_depth': 9})
# (79.912855407318133, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 870, 'random_state': 0, 'max_features': 0.3749718302165917, 'max_depth': 2})
# (141.44417594498651, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.017735317275677565, 'max_depth': 1})
# (71.618061956399359, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 131, 'random_state': 0, 'max_features': 0.48200249381203525, 'max_depth': 4})
# (72.829310089716131, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 844, 'random_state': 0, 'max_features': 0.828068587249032, 'max_depth': 8})
# (71.549391308387044, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 837, 'random_state': 0, 'max_features': 0.5705509243994309, 'max_depth': 5})
# (71.960595118079851, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 390, 'random_state': 0, 'max_features': 0.29268891713406747, 'max_depth': 5})
# (71.560811910274538, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 521, 'random_state': 0, 'max_features': 0.506065628335682, 'max_depth': 5})
# (103.00784961039463, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 215, 'random_state': 0, 'max_features': 0.3375995523335929, 'max_depth': 1})
# (73.399788239628535, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 152, 'random_state': 0, 'max_features': 0.15352477551344107, 'max_depth': 5})
# (104.5185907456621, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 573, 'random_state': 0, 'max_features': 0.9703307217524643, 'max_depth': 1})
# (71.710287110852519, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 733, 'random_state': 0, 'max_features': 0.3545757952112574, 'max_depth': 4})
# (92.189876666179174, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 475, 'random_state': 0, 'max_features': 0.06039464830797441, 'max_depth': 3})
# (72.013323296130963, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 675, 'random_state': 0, 'max_features': 0.27516094332530644, 'max_depth': 5})
# (72.586733134663433, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 658, 'random_state': 0, 'max_features': 0.3956887847717446, 'max_depth': 3})
# (81.269534329656452, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 397, 'random_state': 0, 'max_features': 0.3272378139820999, 'max_depth': 2})
# (72.957717455129341, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 297, 'random_state': 0, 'max_features': 0.7936013295633086, 'max_depth': 8})
# (73.84076729990575, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 378, 'random_state': 0, 'max_features': 0.8882946879237669, 'max_depth': 9})
# (102.82502497190846, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 440, 'random_state': 0, 'max_features': 0.3461076413086346, 'max_depth': 1})
# (73.086449973170289, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 867, 'random_state': 0, 'max_features': 0.8240917000472758, 'max_depth': 7})
# (77.827059003277625, 71.380426698719816, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0, 'max_features': 0.14856739893456639, 'max_depth': 4})
# (71.576493912437428, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 120, 'random_state': 0, 'max_features': 0.5767583787680831, 'max_depth': 5})
# (130.43593322350043, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 713, 'random_state': 0, 'max_features': 0.044514725582810735, 'max_depth': 1})
# (71.89557115092515, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 312, 'random_state': 0, 'max_features': 0.9842391375323853, 'max_depth': 3})
# (71.962045306108394, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 516, 'random_state': 0, 'max_features': 0.39945130846515997, 'max_depth': 7})
# (72.081114994703185, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 282, 'random_state': 0, 'max_features': 0.48212170734995113, 'max_depth': 7})
# (78.836388670601877, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 271, 'random_state': 0, 'max_features': 0.10177732832179981, 'max_depth': 4})
# (71.768151357471226, 71.576493912437428, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 81, 'random_state': 0, 'max_features': 0.3992567422691244, 'max_depth': 6})
# (71.45833739246909, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 681, 'random_state': 0, 'max_features': 0.3372855375685715, 'max_depth': 4})
# (71.7717051195457, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 724, 'random_state': 0, 'max_features': 0.5701510944053688, 'max_depth': 5})
# (73.586149606377958, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 210, 'random_state': 0, 'max_features': 0.28110074806722185, 'max_depth': 3})
# (71.855000559541494, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 487, 'random_state': 0, 'max_features': 0.9900134564921655, 'max_depth': 3})
# (72.133304262419955, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 791, 'random_state': 0, 'max_features': 0.5391877753171671, 'max_depth': 6})
# (71.96531096427708, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 428, 'random_state': 0, 'max_features': 0.5235134726666003, 'max_depth': 7})
# (73.250404557978342, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 597, 'random_state': 0, 'max_features': 0.45536882647413146, 'max_depth': 8})
# (72.078264771378741, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 316, 'random_state': 0, 'max_features': 0.29544786801298856, 'max_depth': 4})
# (72.449636720200147, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 151, 'random_state': 0, 'max_features': 0.8860295636320548, 'max_depth': 6})
# (71.783685702446093, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 118, 'random_state': 0, 'max_features': 0.6176066361657784, 'max_depth': 3})
# (108.60576449935149, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 878, 'random_state': 0, 'max_features': 0.19447844911974127, 'max_depth': 1})
# (76.117466187010905, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 508, 'random_state': 0, 'max_features': 0.13971077953796493, 'max_depth': 4})
# (148.33755519965956, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 655, 'random_state': 0, 'max_features': 0.01320944104480058, 'max_depth': 1})
# (103.27375012052158, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 871, 'random_state': 0, 'max_features': 0.5946225185735988, 'max_depth': 1})
# (73.031951120574803, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 25, 'random_state': 0, 'max_features': 0.2079901022592585, 'max_depth': 5})
# (71.527542999852784, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 362, 'random_state': 0, 'max_features': 0.6419543303511378, 'max_depth': 5})
# (104.21613991440839, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 899, 'random_state': 0, 'max_features': 0.7328918186501806, 'max_depth': 1})
# (72.877438674309985, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 470, 'random_state': 0, 'max_features': 0.2696358487709273, 'max_depth': 8})
# (73.323778265686201, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 184, 'random_state': 0, 'max_features': 0.905917965024024, 'max_depth': 7})
# (72.250349845292774, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 636, 'random_state': 0, 'max_features': 0.22323456208604273, 'max_depth': 6})
# (72.090816106538327, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 231, 'random_state': 0, 'max_features': 0.8418693850521647, 'max_depth': 5})
# (108.79484768693352, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 775, 'random_state': 0, 'max_features': 0.19546863675307793, 'max_depth': 1})
# (81.593342027421656, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 200, 'random_state': 0, 'max_features': 0.1222980306701147, 'max_depth': 3})
# (76.79757899375916, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 239, 'random_state': 0, 'max_features': 0.09812004911400504, 'max_depth': 5})
# (104.26243310197428, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 815, 'random_state': 0, 'max_features': 0.7479678294392371, 'max_depth': 1})
# (71.641075376000614, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 72, 'random_state': 0, 'max_features': 0.577050977417466, 'max_depth': 5})
# (71.471344845997763, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 678, 'random_state': 0, 'max_features': 0.6450108038652381, 'max_depth': 5})
# (77.562819326613919, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 407, 'random_state': 0, 'max_features': 0.466492102531496, 'max_depth': 2})
# (72.615522361644736, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 152, 'random_state': 0, 'max_features': 0.31654118865102376, 'max_depth': 7})
# (104.49741492261323, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 542, 'random_state': 0, 'max_features': 0.9769439886457306, 'max_depth': 1})
# (72.776023078183712, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 809, 'random_state': 0, 'max_features': 0.593969441745301, 'max_depth': 9})
# (102.43053771646696, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 744, 'random_state': 0, 'max_features': 0.3544401462454449, 'max_depth': 1})
# (72.160372381180821, 71.45833739246909, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 184, 'random_state': 0, 'max_features': 0.25015595419336956, 'max_depth': 6})
# (71.639248182982655, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.5993138603303905, 'seed': 0, 'colsample_bytree': 0.9594281803369485, 'nrounds': 726, 'objective': 'reg:linear', 'learning_rate': 0.0075973111105993897, 'max_depth': 2, 'min_child_weight': 1})
# (82.634150960638834, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.9089490479882777, 'seed': 0, 'colsample_bytree': 0.34295082096109974, 'nrounds': 580, 'objective': 'reg:linear', 'learning_rate': 0.050262682732745388, 'max_depth': 7, 'min_child_weight': 3})
# (73.710122572739948, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.5811010880029127, 'seed': 0, 'colsample_bytree': 0.25966143454756674, 'nrounds': 689, 'objective': 'reg:linear', 'learning_rate': 0.050013539788470583, 'max_depth': 2, 'min_child_weight': 1})
# (75.816183025375466, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.9128705663838813, 'seed': 0, 'colsample_bytree': 0.10834964141322094, 'nrounds': 496, 'objective': 'reg:linear', 'learning_rate': 0.010512623727270265, 'max_depth': 3, 'min_child_weight': 4})
# (1640.4334174341946, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.7233460597222812, 'seed': 0, 'colsample_bytree': 0.8859808711524766, 'nrounds': 635, 'objective': 'reg:linear', 'learning_rate': 0.0014733591483789008, 'max_depth': 7, 'min_child_weight': 1})
# (919.97349197626863, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.34199821132739294, 'seed': 0, 'colsample_bytree': 0.22877122404236944, 'nrounds': 660, 'objective': 'reg:linear', 'learning_rate': 0.0019090341328944348, 'max_depth': 1, 'min_child_weight': 4})
# (237.18341771926558, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.010903790345460887, 'seed': 0, 'colsample_bytree': 0.17273324092614561, 'nrounds': 439, 'objective': 'reg:linear', 'learning_rate': 0.0053325422280641709, 'max_depth': 5, 'min_child_weight': 3})
# (77.350298385641906, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.01599992811039746, 'seed': 0, 'colsample_bytree': 0.2970531163118662, 'nrounds': 395, 'objective': 'reg:linear', 'learning_rate': 0.019188215811639167, 'max_depth': 8, 'min_child_weight': 3})
# (2096.8284102515599, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.3641075070491128, 'seed': 0, 'colsample_bytree': 0.4162182910920548, 'nrounds': 625, 'objective': 'reg:linear', 'learning_rate': 0.0013019159846421231, 'max_depth': 1, 'min_child_weight': 3})
# (85.874644087942869, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.8764830688713233, 'seed': 0, 'colsample_bytree': 0.76761193802807, 'nrounds': 457, 'objective': 'reg:linear', 'learning_rate': 0.078998441379111245, 'max_depth': 8, 'min_child_weight': 4})
# (76.829769040787852, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.14306840581507066, 'seed': 0, 'colsample_bytree': 0.8849588531195807, 'nrounds': 553, 'objective': 'reg:linear', 'learning_rate': 0.020482765871468921, 'max_depth': 3, 'min_child_weight': 1})
# (2108.9977753595067, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.7283682921831574, 'seed': 0, 'colsample_bytree': 0.9822382905375491, 'nrounds': 448, 'objective': 'reg:linear', 'learning_rate': 0.0017955218539281496, 'max_depth': 6, 'min_child_weight': 4})
# (345.45137180694093, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.8482473801191305, 'seed': 0, 'colsample_bytree': 0.15535212193879497, 'nrounds': 340, 'objective': 'reg:linear', 'learning_rate': 0.0053667903003542274, 'max_depth': 4, 'min_child_weight': 2})
# (73.79338357607557, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.7196111209266931, 'seed': 0, 'colsample_bytree': 0.6644176962972929, 'nrounds': 685, 'objective': 'reg:linear', 'learning_rate': 0.0086011953732212706, 'max_depth': 7, 'min_child_weight': 4})
# (77.028167955113503, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.47743018338573584, 'seed': 0, 'colsample_bytree': 0.28651676994627673, 'nrounds': 626, 'objective': 'reg:linear', 'learning_rate': 0.027822712321909734, 'max_depth': 5, 'min_child_weight': 4})
# (1843.8741028368761, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.2788702906833989, 'seed': 0, 'colsample_bytree': 0.9410663574954996, 'nrounds': 555, 'objective': 'reg:linear', 'learning_rate': 0.0015829439088930167, 'max_depth': 2, 'min_child_weight': 3})
# (271.28728581992317, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.20904596335968925, 'seed': 0, 'colsample_bytree': 0.5980795309569709, 'nrounds': 673, 'objective': 'reg:linear', 'learning_rate': 0.0030100018633162301, 'max_depth': 1, 'min_child_weight': 2})
# (2244.4013467025125, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.6686576615132364, 'seed': 0, 'colsample_bytree': 0.7031103102211081, 'nrounds': 700, 'objective': 'reg:linear', 'learning_rate': 0.0011039281629892865, 'max_depth': 9, 'min_child_weight': 2})
# (92.369275757783655, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.18508406060257013, 'seed': 0, 'colsample_bytree': 0.10061429968341487, 'nrounds': 766, 'objective': 'reg:linear', 'learning_rate': 0.00447944187540774, 'max_depth': 8, 'min_child_weight': 2})
# (77.92741372491453, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.020342880943013984, 'seed': 0, 'colsample_bytree': 0.7858643382309053, 'nrounds': 641, 'objective': 'reg:linear', 'learning_rate': 0.0079539147596539832, 'max_depth': 4, 'min_child_weight': 2})
# (104.27383115689946, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.7429272438416274, 'seed': 0, 'colsample_bytree': 0.24804403577173714, 'nrounds': 364, 'objective': 'reg:linear', 'learning_rate': 0.0086858837490259716, 'max_depth': 1, 'min_child_weight': 4})
# (91.840184297337245, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.1944554291175356, 'seed': 0, 'colsample_bytree': 0.5076587338615223, 'nrounds': 779, 'objective': 'reg:linear', 'learning_rate': 0.071238948063978041, 'max_depth': 5, 'min_child_weight': 3})
# (83.33240887402448, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.34670576111437557, 'seed': 0, 'colsample_bytree': 0.831468384326815, 'nrounds': 759, 'objective': 'reg:linear', 'learning_rate': 0.030705010446595075, 'max_depth': 7, 'min_child_weight': 2})
# (1418.907980876475, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.9629146948031647, 'seed': 0, 'colsample_bytree': 0.37884654872942675, 'nrounds': 576, 'objective': 'reg:linear', 'learning_rate': 0.0017573294673997137, 'max_depth': 9, 'min_child_weight': 4})
# (4859.6266872085043, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.17791410710226999, 'seed': 0, 'colsample_bytree': 0.9373162003944898, 'nrounds': 330, 'objective': 'reg:linear', 'learning_rate': 0.0011476105554449406, 'max_depth': 7, 'min_child_weight': 4})
# (79.417969684081967, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.44986162084075865, 'seed': 0, 'colsample_bytree': 0.3597001368018667, 'nrounds': 606, 'objective': 'reg:linear', 'learning_rate': 0.071194808954902183, 'max_depth': 3, 'min_child_weight': 1})
# (1989.599990353739, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.7570011930768034, 'seed': 0, 'colsample_bytree': 0.1219921368037503, 'nrounds': 684, 'objective': 'reg:linear', 'learning_rate': 0.0012277186673728647, 'max_depth': 9, 'min_child_weight': 3})
# (98.970180876599628, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.43411116506332004, 'seed': 0, 'colsample_bytree': 0.012996232732940413, 'nrounds': 557, 'objective': 'reg:linear', 'learning_rate': 0.015390201168836135, 'max_depth': 9, 'min_child_weight': 4})
# (81.523938716505072, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.6203359538807566, 'seed': 0, 'colsample_bytree': 0.07868781958558849, 'nrounds': 619, 'objective': 'reg:linear', 'learning_rate': 0.04407241352484801, 'max_depth': 8, 'min_child_weight': 2})
# (216.3432606268893, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.942312118944303, 'seed': 0, 'colsample_bytree': 0.07178501363246562, 'nrounds': 726, 'objective': 'reg:linear', 'learning_rate': 0.0030186776976759808, 'max_depth': 6, 'min_child_weight': 3})
# (73.865245514307006, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.2148545756414102, 'seed': 0, 'colsample_bytree': 0.260158647239867, 'nrounds': 563, 'objective': 'reg:linear', 'learning_rate': 0.031078700685330772, 'max_depth': 2, 'min_child_weight': 1})
# (169.65051517173387, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.1789653467290441, 'seed': 0, 'colsample_bytree': 0.6597093373574198, 'nrounds': 402, 'objective': 'reg:linear', 'learning_rate': 0.0059140582732416409, 'max_depth': 8, 'min_child_weight': 2})
# (126.62233780608786, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.2470844028035633, 'seed': 0, 'colsample_bytree': 0.7609636213947928, 'nrounds': 763, 'objective': 'reg:linear', 'learning_rate': 0.0034808103958814665, 'max_depth': 5, 'min_child_weight': 1})
# (78.104950590337452, 71.639248182982655, {'num_parallel_tree': 1, 'subsample': 0.2759256224133154, 'seed': 0, 'colsample_bytree': 0.804060474219005, 'nrounds': 702, 'objective': 'reg:linear', 'learning_rate': 0.025016028358505214, 'max_depth': 4, 'min_child_weight': 3})
# (84.512002829079293, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.18201505161765522, 'seed': 0, 'colsample_bytree': 0.27091741612101794, 'nrounds': 463, 'objective': 'reg:linear', 'learning_rate': 0.0075822499400161744, 'max_depth': 3, 'min_child_weight': 1})
# (75.965595012218273, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.042812802686432894, 'seed': 0, 'colsample_bytree': 0.20126764051236912, 'nrounds': 681, 'objective': 'reg:linear', 'learning_rate': 0.014720370183391705, 'max_depth': 8, 'min_child_weight': 3})
# (749.28835545430445, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.12316199804856671, 'seed': 0, 'colsample_bytree': 0.4491295731697186, 'nrounds': 392, 'objective': 'reg:linear', 'learning_rate': 0.0035004812565447674, 'max_depth': 6, 'min_child_weight': 3})
# (2137.1154192124063, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.8390268508662135, 'seed': 0, 'colsample_bytree': 0.4698994568714527, 'nrounds': 514, 'objective': 'reg:linear', 'learning_rate': 0.0015614958524188924, 'max_depth': 1, 'min_child_weight': 4})
# (211.07674994693647, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.786509065505783, 'seed': 0, 'colsample_bytree': 0.7268019616536724, 'nrounds': 469, 'objective': 'reg:linear', 'learning_rate': 0.0045784367995356165, 'max_depth': 4, 'min_child_weight': 1})
# (83.157373079115146, 71.639248182982655, {'num_parallel_tree': 2, 'subsample': 0.4636377283771384, 'seed': 0, 'colsample_bytree': 0.9710039246763956, 'nrounds': 648, 'objective': 'reg:linear', 'learning_rate': 0.0064690062237668421, 'max_depth': 1, 'min_child_weight': 4})

# %% [markdown]
# # Second Layer

# %%
xgb_data = pickle.load(open('xgb.p','rb'), encoding='latin1')
et_data = pickle.load(open('et.p','rb'), encoding='latin1')
rf_data = pickle.load(open('rf.p','rb'), encoding='latin1')
L = 1
N = 3
X_val_bar = np.zeros([842, L*N])
X_test_bar = np.zeros([4209, L*N])
id_col = (i for i in range(L*N)) 
for dt in sorted(et_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])

for dt in sorted(rf_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])
for dt in sorted(xgb_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9bde2ce6ae1c> in <module>()
# ----> 1 xgb_data = pickle.load(open('xgb.p','rb'), encoding='latin1')
#       2 et_data = pickle.load(open('et.p','rb'), encoding='latin1')
#       3 rf_data = pickle.load(open('rf.p','rb'), encoding='latin1')
#       4 L = 1
#       5 N = 3
#
# TypeError: load() got an unexpected keyword argument 'encoding'

# %%
def get_oof_2nd_layer(clf,X_train,y_train, X_val):
    ntrain = X_train.shape[0]
    nval = X_val.shape[0]
    oof_train = np.zeros((ntrain,))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))
    kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)
    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]
        clf.train(X_tr, y_tr)
        oof_train[test_index] = clf.predict(X_te)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1)

def turing_2nd_layer(clf,N):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_val, oof_test = get_oof_2nd_layer(model, X_val_bar, y_val, X_test_bar)
        err = mean_squared_error(y_val, oof_val)
        if best_err > err:
            best_err = err
            best_para = params
            best_y = oof_test
        print(err,best_err, params)
    #pickle.dump(best_para,open("2nd_layer_para.p",'wb'))
    return best_y

# %%
best_y = turing_2nd_layer(RandomForestRegressor, 40)

# %%
submission = pd.read_csv(SUBMISSION_FILE)
submission.iloc[:, 1] = best_y
submission.to_csv('stacking_sub.csv', index=None)
