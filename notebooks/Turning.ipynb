# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import pickle
from scipy.stats import randint as sp_randint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor

# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
# Out:
# /home/haoyuan/assignment1/.env/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def data_with_val():
    print('generating data......')
    # read datasets
    train_total = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

    # Shuffle data
    np.random.seed(0)
    l = [x for x in range(4209)]
    np.random.shuffle(l)
    train_total = train_total.iloc[l]

    # split data
    ratio = 0.5
    threshold = int(ratio*4209)
    X_train = train_total.iloc[range(threshold)] 
    val = train_total.iloc[range(threshold, 4209)]
    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)
    y_val = val['y']
    X_val = val.drop('y', axis = 1)

    # process type
    for c in train_total.columns:
        if train_total[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(train_total[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_val[c] = lbl.transform(list(X_val[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    print('Shape X_val:', X_val.shape )
    return X_train, y_train, X_val, y_val, X_test

def data():
    print('generating data......')
    # read datasets
    X_train = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

#     # Shuffle data
#     l = [x for x in range(4209)]
#     np.random.seed(0)
#     np.random.shuffle(l)
#     X_train = X_train.iloc[l]

    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)

    # process type
    for c in X_train.columns:
        if X_train[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(X_train[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    return X_train, y_train, X_test

# %%
X_train,y_train, X_val,y_val, X_test = data_with_val()
#X_train,y_train, X_test = data()
#X_val,y_val = X_train[:],y_train[:]
# Out:
# generating data......
# ('Shape X_train:', (2104, 377))
# ('Shape X_test:', (4209, 377))
# ('Shape X_val:', (2105, 377))

# %%
# Gloable data

ID = 'ID'
TARGET = 'y'
NFOLDS = 4
SEED = 1
NROWS = None
DATA_DIR = "../data"
SUBMISSION_FILE = "{0}/sample_submission.csv".format(DATA_DIR)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)

SEED = 0
ntrain, D = X_train.shape
nval = X_val.shape[0]
ntest = X_test.shape[0]
NFOLDS = 4

kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, X_train, y_train):
        self.clf.fit(X_train, y_train)

    def predict(self, X):
        return self.clf.predict(X)
    

class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        params = params.copy() # creat a local version of params
        self.nrounds = params.pop('nrounds', 250)

    def train(self, X_train, y_train):
        dtrain = xgb.DMatrix(X_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, X):
        return self.gbdt.predict(xgb.DMatrix(X))
    

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))

    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]

        clf.train(X_tr, y_tr)

        oof_train[test_index] = clf.predict(X_te)
        oof_test_skf[i, :] = clf.predict(X_test)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_test[:] = oof_test_skf.mean(axis=0)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
def turing_xgb(N):
    best_err = 100000000
    data = []
    for _ in range(N):
        params = {
            'colsample_bytree': np.random.uniform(0.01,1),
            'subsample': np.random.uniform(0.01,1),
            'learning_rate': np.exp(np.random.uniform(np.log(0.001),np.log(0.1))),
            'objective': 'reg:linear',
            'max_depth': int(np.random.uniform(1,10)),
            'num_parallel_tree': int(np.random.uniform(1,3)),
            'min_child_weight': int(np.random.uniform(1,5)),
            'nrounds': int(np.random.uniform(300,800))
        }
        model = XgbWrapper(seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err, oof_train, oof_val, oof_test)]

    pickle.dump(data,open("xgb.p",'wb'))    
    
def turing(clf,N,name):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err,oof_train, oof_val, oof_test)]

    pickle.dump(data,open("{}.p".format(name),'wb'))

# %%
N = 100
turing(RandomForestRegressor,N,'rf')
turing(ExtraTreesRegressor,N,'et')
turing_xgb(N)
# Out:
# (100.21713377336098, 100.21713377336098, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 286, 'random_state': 0, 'max_features': 0.024499432235574173, 'max_depth': 5})
# (76.199222999935003, 76.199222999935003, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 811, 'random_state': 0, 'max_features': 0.7649142272517786, 'max_depth': 5})
# (81.929948152242801, 76.199222999935003, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 502, 'random_state': 0, 'max_features': 0.8861720323891933, 'max_depth': 8})
# (77.244681393984877, 76.199222999935003, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 606, 'random_state': 0, 'max_features': 0.16160041019820734, 'max_depth': 8})
# (77.271056158471509, 76.199222999935003, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 777, 'random_state': 0, 'max_features': 0.2976875139014636, 'max_depth': 6})
# (76.10457496427118, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 877, 'random_state': 0, 'max_features': 0.4153271175045414, 'max_depth': 5})
# (123.55847888118848, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 572, 'random_state': 0, 'max_features': 0.0873765381289197, 'max_depth': 1})
# (76.123232191434042, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 166, 'random_state': 0, 'max_features': 0.408680141828105, 'max_depth': 4})
# (108.87908474241408, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 691, 'random_state': 0, 'max_features': 0.8460364875625905, 'max_depth': 1})
# (80.865900641636401, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 17, 'random_state': 0, 'max_features': 0.14467786838552604, 'max_depth': 4})
# (108.97676255301515, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 432, 'random_state': 0, 'max_features': 0.9726737152291963, 'max_depth': 1})
# (78.561000236776863, 76.10457496427118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 161, 'random_state': 0, 'max_features': 0.4335969539846919, 'max_depth': 7})
# (76.074137997724947, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 75, 'random_state': 0, 'max_features': 0.7667115870795428, 'max_depth': 4})
# (77.254119562951558, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 418, 'random_state': 0, 'max_features': 0.6903673404124713, 'max_depth': 7})
# (81.695222575059915, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 786, 'random_state': 0, 'max_features': 0.6129454437053583, 'max_depth': 2})
# (108.99099069137247, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.9940295709516269, 'max_depth': 1})
# (77.464765088964796, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 607, 'random_state': 0, 'max_features': 0.26333657849004677, 'max_depth': 8})
# (77.510152420187424, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 527, 'random_state': 0, 'max_features': 0.8143066365736331, 'max_depth': 8})
# (76.619391373376075, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 873, 'random_state': 0, 'max_features': 0.7387646171979815, 'max_depth': 6})
# (77.467050032282543, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 211, 'random_state': 0, 'max_features': 0.39805053080537056, 'max_depth': 9})
# (84.054747046009879, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 870, 'random_state': 0, 'max_features': 0.3749718302165917, 'max_depth': 2})
# (142.7011517627775, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 47, 'random_state': 0, 'max_features': 0.017735317275677565, 'max_depth': 1})
# (76.14524424208976, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 131, 'random_state': 0, 'max_features': 0.48200249381203525, 'max_depth': 4})
# (77.607801597877952, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 844, 'random_state': 0, 'max_features': 0.828068587249032, 'max_depth': 8})
# (76.261151100203506, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 837, 'random_state': 0, 'max_features': 0.5705509243994309, 'max_depth': 5})
# (76.206180634488121, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 390, 'random_state': 0, 'max_features': 0.29268891713406747, 'max_depth': 5})
# (77.084928783178711, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 521, 'random_state': 0, 'max_features': 0.506065628335682, 'max_depth': 5})
# (106.90592914304062, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 215, 'random_state': 0, 'max_features': 0.3375995523335929, 'max_depth': 1})
# (77.683639822769422, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 152, 'random_state': 0, 'max_features': 0.15352477551344107, 'max_depth': 5})
# (108.97596759624368, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 573, 'random_state': 0, 'max_features': 0.9703307217524643, 'max_depth': 1})
# (76.360663710734329, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 733, 'random_state': 0, 'max_features': 0.3545757952112574, 'max_depth': 4})
# (96.421044103775344, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 475, 'random_state': 0, 'max_features': 0.06039464830797441, 'max_depth': 3})
# (76.313189263218419, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 675, 'random_state': 0, 'max_features': 0.27516094332530644, 'max_depth': 5})
# (77.015996916666666, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 658, 'random_state': 0, 'max_features': 0.3956887847717446, 'max_depth': 3})
# (85.160887321509477, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 397, 'random_state': 0, 'max_features': 0.3272378139820999, 'max_depth': 2})
# (77.493864053692704, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 297, 'random_state': 0, 'max_features': 0.7936013295633086, 'max_depth': 8})
# (78.615274144198708, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 378, 'random_state': 0, 'max_features': 0.8882946879237669, 'max_depth': 9})
# (106.77800492348159, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 440, 'random_state': 0, 'max_features': 0.3461076413086346, 'max_depth': 1})
# (80.571341527567654, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 867, 'random_state': 0, 'max_features': 0.8240917000472758, 'max_depth': 7})
# (79.863672004643746, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 10, 'random_state': 0, 'max_features': 0.14856739893456639, 'max_depth': 4})
# (77.838611230594438, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 120, 'random_state': 0, 'max_features': 0.5767583787680831, 'max_depth': 5})
# (132.73641534883814, 76.074137997724947, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 713, 'random_state': 0, 'max_features': 0.044514725582810735, 'max_depth': 1})
# (76.05148067284118, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 312, 'random_state': 0, 'max_features': 0.9842391375323853, 'max_depth': 3})
# (76.938341700934501, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 516, 'random_state': 0, 'max_features': 0.39945130846515997, 'max_depth': 7})
# (76.897445364336619, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 282, 'random_state': 0, 'max_features': 0.48212170734995113, 'max_depth': 7})
# (82.715111421455305, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 271, 'random_state': 0, 'max_features': 0.10177732832179981, 'max_depth': 4})
# (76.658509600827259, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 81, 'random_state': 0, 'max_features': 0.3992567422691244, 'max_depth': 6})
# (76.523862836789732, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 681, 'random_state': 0, 'max_features': 0.3372855375685715, 'max_depth': 4})
# (76.068571511100359, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 724, 'random_state': 0, 'max_features': 0.5701510944053688, 'max_depth': 5})
# (78.228688137979674, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 210, 'random_state': 0, 'max_features': 0.28110074806722185, 'max_depth': 3})
# (76.113718239057945, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 487, 'random_state': 0, 'max_features': 0.9900134564921655, 'max_depth': 3})
# (76.503914879226528, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 791, 'random_state': 0, 'max_features': 0.5391877753171671, 'max_depth': 6})
# (77.0631295405678, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 428, 'random_state': 0, 'max_features': 0.5235134726666003, 'max_depth': 7})
# (77.981025128866349, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 597, 'random_state': 0, 'max_features': 0.45536882647413146, 'max_depth': 8})
# (76.617460399936988, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 316, 'random_state': 0, 'max_features': 0.29544786801298856, 'max_depth': 4})
# (76.950815307923193, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 151, 'random_state': 0, 'max_features': 0.8860295636320548, 'max_depth': 6})
# (76.143319691168813, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 118, 'random_state': 0, 'max_features': 0.6176066361657784, 'max_depth': 3})
# (111.72431378609642, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 878, 'random_state': 0, 'max_features': 0.19447844911974127, 'max_depth': 1})
# (79.942475484090167, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 508, 'random_state': 0, 'max_features': 0.13971077953796493, 'max_depth': 4})
# (147.84854520351703, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 655, 'random_state': 0, 'max_features': 0.01320944104480058, 'max_depth': 1})
# (107.90431930409233, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 871, 'random_state': 0, 'max_features': 0.5946225185735988, 'max_depth': 1})
# (76.704737134511134, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 25, 'random_state': 0, 'max_features': 0.2079901022592585, 'max_depth': 5})
# (76.328709667417598, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 362, 'random_state': 0, 'max_features': 0.6419543303511378, 'max_depth': 5})
# (108.62015135844801, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 899, 'random_state': 0, 'max_features': 0.7328918186501806, 'max_depth': 1})
# (77.618013595141136, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 470, 'random_state': 0, 'max_features': 0.2696358487709273, 'max_depth': 8})
# (77.430386458095441, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 184, 'random_state': 0, 'max_features': 0.905917965024024, 'max_depth': 7})
# (76.783894890353324, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 636, 'random_state': 0, 'max_features': 0.22323456208604273, 'max_depth': 6})
# (76.268088579365937, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 231, 'random_state': 0, 'max_features': 0.8418693850521647, 'max_depth': 5})
# (111.92827017742732, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 775, 'random_state': 0, 'max_features': 0.19546863675307793, 'max_depth': 1})
# (85.385027222239017, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 200, 'random_state': 0, 'max_features': 0.1222980306701147, 'max_depth': 3})
# (80.359835773855153, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 239, 'random_state': 0, 'max_features': 0.09812004911400504, 'max_depth': 5})
# (108.64462943239251, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 815, 'random_state': 0, 'max_features': 0.7479678294392371, 'max_depth': 1})
# (77.631450285513267, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 72, 'random_state': 0, 'max_features': 0.577050977417466, 'max_depth': 5})
# (76.29927008792238, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 678, 'random_state': 0, 'max_features': 0.6450108038652381, 'max_depth': 5})
# (82.478781008463841, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 407, 'random_state': 0, 'max_features': 0.466492102531496, 'max_depth': 2})
# (77.217334856793073, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 152, 'random_state': 0, 'max_features': 0.31654118865102376, 'max_depth': 7})
# (108.97849098864431, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 542, 'random_state': 0, 'max_features': 0.9769439886457306, 'max_depth': 1})
# (77.663084079248279, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 809, 'random_state': 0, 'max_features': 0.593969441745301, 'max_depth': 9})
# (106.69424477702428, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 744, 'random_state': 0, 'max_features': 0.3544401462454449, 'max_depth': 1})
# (76.68955920603895, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 184, 'random_state': 0, 'max_features': 0.25015595419336956, 'max_depth': 6})
# (76.885728093889753, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 863, 'random_state': 0, 'max_features': 0.5993138603303905, 'max_depth': 4})
# (80.694240986098592, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 771, 'random_state': 0, 'max_features': 0.053822206836588254, 'max_depth': 8})
# (80.723606129503636, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 817, 'random_state': 0, 'max_features': 0.8521166041825705, 'max_depth': 7})
# (76.13815894140572, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 622, 'random_state': 0, 'max_features': 0.5662066943119154, 'max_depth': 3})
# (77.49867225104343, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 764, 'random_state': 0, 'max_features': 0.218545107984211, 'max_depth': 4})
# (77.630092636193552, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 700, 'random_state': 0, 'max_features': 0.10834964141322094, 'max_depth': 9})
# (78.556977058009238, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 246, 'random_state': 0, 'max_features': 0.07932618308363674, 'max_depth': 8})
# (108.59218115242366, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 796, 'random_state': 0, 'max_features': 0.7233460597222812, 'max_depth': 1})
# (77.829402784133862, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 740, 'random_state': 0, 'max_features': 0.10918325999694681, 'max_depth': 7})
# (115.71045719705563, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 302, 'random_state': 0, 'max_features': 0.1490027782843647, 'max_depth': 1})
# (81.906962194233117, 76.05148067284118, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 839, 'random_state': 0, 'max_features': 0.7245548738913545, 'max_depth': 2})
# (76.044702443634193, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 327, 'random_state': 0, 'max_features': 0.5498608542826325, 'max_depth': 4})
# (107.53474885671247, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 251, 'random_state': 0, 'max_features': 0.2970531163118662, 'max_depth': 1})
# (77.1202684465418, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 761, 'random_state': 0, 'max_features': 0.917080614076076, 'max_depth': 6})
# (106.73794230925688, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 369, 'random_state': 0, 'max_features': 0.3641075070491128, 'max_depth': 1})
# (76.563017981131253, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 280, 'random_state': 0, 'max_features': 0.7122064929543497, 'max_depth': 6})
# (82.195175084451137, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 787, 'random_state': 0, 'max_features': 0.949321168808657, 'max_depth': 8})
# (78.772898635957247, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 871, 'random_state': 0, 'max_features': 0.32158052083324007, 'max_depth': 8})
# (78.791677981557882, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 590, 'random_state': 0, 'max_features': 0.32805208640379174, 'max_depth': 8})
# (81.05680813986946, 76.044702443634193, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 457, 'random_state': 0, 'max_features': 0.9822382905375491, 'max_depth': 7})
# (79.949699083898338, 79.949699083898338, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 592, 'random_state': 0, 'max_features': 0.6746827099957803, 'max_depth': 8})
# (76.91636424734827, 76.91636424734827, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 132, 'random_state': 0, 'max_features': 0.8482473801191305, 'max_depth': 4})
# (106.66991593414271, 76.91636424734827, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 863, 'random_state': 0, 'max_features': 0.4639062505613176, 'max_depth': 1})
# (77.80214980149087, 76.91636424734827, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 645, 'random_state': 0, 'max_features': 0.47260661225151257, 'max_depth': 7})
# (75.989566069995647, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 810, 'random_state': 0, 'max_features': 0.7728906165884083, 'max_depth': 3})
# (76.028122169837204, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 650, 'random_state': 0, 'max_features': 0.538833002518169, 'max_depth': 5})
# (82.392559889956573, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 587, 'random_state': 0, 'max_features': 0.9410663574954996, 'max_depth': 3})
# (76.597441415520166, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 168, 'random_state': 0, 'max_features': 0.1979294166642855, 'max_depth': 5})
# (80.751055258186483, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 535, 'random_state': 0, 'max_features': 0.20904596335968925, 'max_depth': 3})
# (76.757702405755396, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 23, 'random_state': 0, 'max_features': 0.36189645264626613, 'max_depth': 7})
# (85.15413216067877, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 599, 'random_state': 0, 'max_features': 0.031255702453670306, 'max_depth': 9})
# (108.69797665377072, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 391, 'random_state': 0, 'max_features': 0.8032407336342198, 'max_depth': 1})
# (79.695979974260666, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 293, 'random_state': 0, 'max_features': 0.8449520067728202, 'max_depth': 7})
# (108.72728926185475, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 840, 'random_state': 0, 'max_features': 0.7858643382309053, 'max_depth': 1})
# (79.256346009876737, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 383, 'random_state': 0, 'max_features': 0.24324393080410006, 'max_depth': 3})
# (82.127707472901719, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 217, 'random_state': 0, 'max_features': 0.7429272438416274, 'max_depth': 5})
# (83.091720306254913, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 366, 'random_state': 0, 'max_features': 0.793600582765223, 'max_depth': 2})
# (86.157882212528364, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 168, 'random_state': 0, 'max_features': 0.9270951614673572, 'max_depth': 5})
# (81.925127677403694, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 503, 'random_state': 0, 'max_features': 0.9590054212117246, 'max_depth': 8})
# (78.80516855559371, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 669, 'random_state': 0, 'max_features': 0.6895831479016247, 'max_depth': 7})
# (81.82193793669461, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 827, 'random_state': 0, 'max_features': 0.37884654872942675, 'max_depth': 9})
# (79.954134951523329, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 839, 'random_state': 0, 'max_features': 0.7646730862844315, 'max_depth': 9})
# (113.31524435596715, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 843, 'random_state': 0, 'max_features': 0.17791410710226999, 'max_depth': 1})
# (108.97003760588444, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 777, 'random_state': 0, 'max_features': 0.8979220275519684, 'max_depth': 1})
# (76.105467980372822, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 400, 'random_state': 0, 'max_features': 0.9269619228391176, 'max_depth': 3})
# (81.77284063030929, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 198, 'random_state': 0, 'max_features': 0.6165995021812247, 'max_depth': 2})
# (81.001279598791982, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 41, 'random_state': 0, 'max_features': 0.9983597555303119, 'max_depth': 8})
# (119.9066899436157, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 691, 'random_state': 0, 'max_features': 0.012996232732940413, 'max_depth': 4})
# (77.812238424116529, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 878, 'random_state': 0, 'max_features': 0.37220484091376044, 'max_depth': 9})
# (77.350474230978278, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 63, 'random_state': 0, 'max_features': 0.6203359538807566, 'max_depth': 8})
# (79.595441396449587, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 476, 'random_state': 0, 'max_features': 0.4503682734193342, 'max_depth': 6})
# (76.395468968683545, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 847, 'random_state': 0, 'max_features': 0.2475092893437331, 'max_depth': 6})
# (76.428828094643379, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 649, 'random_state': 0, 'max_features': 0.8549965406522715, 'max_depth': 3})
# (78.082615775500329, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 671, 'random_state': 0, 'max_features': 0.19462381156013678, 'max_depth': 9})
# (81.784374292886454, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 474, 'random_state': 0, 'max_features': 0.6597093373574198, 'max_depth': 2})
# (76.364108158967426, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 701, 'random_state': 0, 'max_features': 0.3071538259428811, 'max_depth': 4})
# (79.170323611165529, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 682, 'random_state': 0, 'max_features': 0.2470844028035633, 'max_depth': 3})
# (77.203139272379204, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 173, 'random_state': 0, 'max_features': 0.23732860543223125, 'max_depth': 9})
# (76.675922925125022, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 242, 'random_state': 0, 'max_features': 0.7021180884758161, 'max_depth': 4})
# (76.310048927852549, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 635, 'random_state': 0, 'max_features': 0.8074031315079101, 'max_depth': 3})
# (77.788166367296455, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 396, 'random_state': 0, 'max_features': 0.2590833123773334, 'max_depth': 8})
# (112.31214092934931, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 294, 'random_state': 0, 'max_features': 0.20126764051236912, 'max_depth': 1})
# (77.808588982906457, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 702, 'random_state': 0, 'max_features': 0.8195509664669931, 'max_depth': 7})
# (86.449483493464754, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 399, 'random_state': 0, 'max_features': 0.12316199804856671, 'max_depth': 3})
# (81.795891583810118, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 836, 'random_state': 0, 'max_features': 0.6831626150123856, 'max_depth': 2})
# (120.60346834568266, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 753, 'random_state': 0, 'max_features': 0.10580271333123469, 'max_depth': 1})
# (76.799439492798797, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 786, 'random_state': 0, 'max_features': 0.4343584041863687, 'max_depth': 7})
# (81.623629341159941, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 297, 'random_state': 0, 'max_features': 0.44187222250292374, 'max_depth': 8})
# (78.388762012943559, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 305, 'random_state': 0, 'max_features': 0.9710039246763956, 'max_depth': 5})
# (79.476575150183393, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 30, 'random_state': 0, 'max_features': 0.7315605545630285, 'max_depth': 9})
# (85.112584235656769, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 591, 'random_state': 0, 'max_features': 0.932723406386958, 'max_depth': 2})
# (78.06558390075341, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 617, 'random_state': 0, 'max_features': 0.08291017597255664, 'max_depth': 9})
# (108.97141856623875, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 698, 'random_state': 0, 'max_features': 0.8989925010081941, 'max_depth': 1})
# (77.958759635692488, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 499, 'random_state': 0, 'max_features': 0.855297301523632, 'max_depth': 6})
# (77.30300235672162, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 516, 'random_state': 0, 'max_features': 0.6690852333969757, 'max_depth': 7})
# (82.428641080124081, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 125, 'random_state': 0, 'max_features': 0.9907277389406686, 'max_depth': 8})
# (77.018742873801514, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 579, 'random_state': 0, 'max_features': 0.27461939501744737, 'max_depth': 8})
# (108.83707447984909, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 237, 'random_state': 0, 'max_features': 0.8424253743428355, 'max_depth': 1})
# (78.170484520569019, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 304, 'random_state': 0, 'max_features': 0.13295636019326051, 'max_depth': 5})
# (81.89174846883347, 75.989566069995647, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 367, 'random_state': 0, 'max_features': 0.6979302501085832, 'max_depth': 2})
# (75.956882004287593, 75.956882004287593, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 154, 'random_state': 0, 'max_features': 0.7042362097054768, 'max_depth': 3})
# (108.69719568137009, 75.956882004287593, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 868, 'random_state': 0, 'max_features': 0.7792557577883613, 'max_depth': 1})
# (84.583000094363385, 75.956882004287593, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 19, 'random_state': 0, 'max_features': 0.9358315991434097, 'max_depth': 2})
# (108.23637031914863, 75.956882004287593, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 660, 'random_state': 0, 'max_features': 0.6792156318183388, 'max_depth': 1})
# (75.841176636734531, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 875, 'random_state': 0, 'max_features': 0.6500296913377822, 'max_depth': 3})
# (77.167553048190683, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 437, 'random_state': 0, 'max_features': 0.12576294998314802, 'max_depth': 8})
# (115.32842254484336, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 25, 'random_state': 0, 'max_features': 0.050302974677654176, 'max_depth': 2})
# (77.947381016441909, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 175, 'random_state': 0, 'max_features': 0.9225065752146916, 'max_depth': 5})
# (78.780846652543232, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 113, 'random_state': 0, 'max_features': 0.5841527242157348, 'max_depth': 9})
# (78.672659085455706, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 391, 'random_state': 0, 'max_features': 0.6287589585076592, 'max_depth': 7})
# (79.174854713764617, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 243, 'random_state': 0, 'max_features': 0.8934290082075551, 'max_depth': 8})
# (76.243988426257829, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 603, 'random_state': 0, 'max_features': 0.5241482200071381, 'max_depth': 4})
# (108.9119358827453, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 72, 'random_state': 0, 'max_features': 0.8873301801002845, 'max_depth': 1})
# (76.551065799518085, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 410, 'random_state': 0, 'max_features': 0.1924419924628895, 'max_depth': 6})
# (78.023404215959218, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 576, 'random_state': 0, 'max_features': 0.37211298345642274, 'max_depth': 8})
# (84.852326813714214, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 350, 'random_state': 0, 'max_features': 0.6301166102812364, 'max_depth': 8})
# (76.518176582686664, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 394, 'random_state': 0, 'max_features': 0.4782497422405021, 'max_depth': 5})
# (79.678021621961278, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 166, 'random_state': 0, 'max_features': 0.23620872371413218, 'max_depth': 3})
# (77.925467201334484, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 498, 'random_state': 0, 'max_features': 0.3384990534475469, 'max_depth': 8})
# (77.751117067453038, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 275, 'random_state': 0, 'max_features': 0.3521804435664694, 'max_depth': 9})
# (77.977364408000511, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 369, 'random_state': 0, 'max_features': 0.8978797911944444, 'max_depth': 7})
# (83.257242444299308, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 145, 'random_state': 0, 'max_features': 0.8043937667065343, 'max_depth': 5})
# (78.980661599931821, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 83, 'random_state': 0, 'max_features': 0.5776644372626963, 'max_depth': 4})
# (83.06518580051258, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 393, 'random_state': 0, 'max_features': 0.7942277851601695, 'max_depth': 2})
# (76.14658190926778, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 384, 'random_state': 0, 'max_features': 0.3354104692671466, 'max_depth': 4})
# (106.9736030468749, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 345, 'random_state': 0, 'max_features': 0.5381225909793338, 'max_depth': 1})
# (76.84986125394704, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 130, 'random_state': 0, 'max_features': 0.17722837702290395, 'max_depth': 7})
# (76.266926459584013, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 813, 'random_state': 0, 'max_features': 0.4628254790727736, 'max_depth': 3})
# (78.619347894751201, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 504, 'random_state': 0, 'max_features': 0.27134845506514543, 'max_depth': 7})
# (79.782077083931156, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 848, 'random_state': 0, 'max_features': 0.7287466643180432, 'max_depth': 8})
# (86.37518997196679, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 838, 'random_state': 0, 'max_features': 0.9902203072242253, 'max_depth': 2})
# (81.303988575822473, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 780, 'random_state': 0, 'max_features': 0.0581806380375652, 'max_depth': 7})
# (121.55561113176759, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 589, 'random_state': 0, 'max_features': 0.1047511672343088, 'max_depth': 1})
# (106.87819817640951, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 336, 'random_state': 0, 'max_features': 0.5110461562256133, 'max_depth': 1})
# (77.458787041952007, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 861, 'random_state': 0, 'max_features': 0.48304771882543085, 'max_depth': 9})
# (76.602195192338129, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 246, 'random_state': 0, 'max_features': 0.8162412490794021, 'max_depth': 4})
# (76.480670482864099, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 293, 'random_state': 0, 'max_features': 0.20470959645174255, 'max_depth': 6})
# (76.606041304799533, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 861, 'random_state': 0, 'max_features': 0.2698988658091379, 'max_depth': 7})
# (77.659825498395449, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 191, 'random_state': 0, 'max_features': 0.5169142457651547, 'max_depth': 9})
# (76.449505104791626, 75.841176636734531, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 11, 'random_state': 0, 'max_features': 0.6279224995593958, 'max_depth': 6})
# (2562.5562582926423, 2562.5562582926423, {'num_parallel_tree': 2, 'subsample': 0.544353502718486, 'seed': 0, 'colsample_bytree': 0.6916266275995497, 'nrounds': 307, 'objective': 'reg:linear', 'learning_rate': 0.0023132304194015138, 'max_depth': 3, 'min_child_weight': 1})
# (85.048566851160288, 85.048566851160288, {'num_parallel_tree': 2, 'subsample': 0.6793761156967997, 'seed': 0, 'colsample_bytree': 0.6152472532008695, 'nrounds': 494, 'objective': 'reg:linear', 'learning_rate': 0.044820637152006938, 'max_depth': 5, 'min_child_weight': 4})
# (91.475034797616331, 85.048566851160288, {'num_parallel_tree': 2, 'subsample': 0.765324327355855, 'seed': 0, 'colsample_bytree': 0.0999013317160665, 'nrounds': 596, 'objective': 'reg:linear', 'learning_rate': 0.085169868422989264, 'max_depth': 8, 'min_child_weight': 1})
# (81.188078506328495, 81.188078506328495, {'num_parallel_tree': 2, 'subsample': 0.5960567142413491, 'seed': 0, 'colsample_bytree': 0.025543527214024316, 'nrounds': 386, 'objective': 'reg:linear', 'learning_rate': 0.046495441365434022, 'max_depth': 7, 'min_child_weight': 1})
# (76.682275254253497, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5955660559767091, 'seed': 0, 'colsample_bytree': 0.8466635056912196, 'nrounds': 614, 'objective': 'reg:linear', 'learning_rate': 0.011060721721024784, 'max_depth': 2, 'min_child_weight': 3})
# (77.341305396777358, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.7507702100815203, 'seed': 0, 'colsample_bytree': 0.7064134028789694, 'nrounds': 595, 'objective': 'reg:linear', 'learning_rate': 0.017446778731670463, 'max_depth': 2, 'min_child_weight': 1})
# (78.556664214703574, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.27457464092018646, 'seed': 0, 'colsample_bytree': 0.9796125912878273, 'nrounds': 796, 'objective': 'reg:linear', 'learning_rate': 0.0060768907504200652, 'max_depth': 3, 'min_child_weight': 1})
# (78.901398378261177, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.6211999686397178, 'seed': 0, 'colsample_bytree': 0.7987862222060825, 'nrounds': 617, 'objective': 'reg:linear', 'learning_rate': 0.0421941540134457, 'max_depth': 2, 'min_child_weight': 4})
# (81.425330747780549, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.4568498570690786, 'seed': 0, 'colsample_bytree': 0.5671318444899047, 'nrounds': 477, 'objective': 'reg:linear', 'learning_rate': 0.019288748804135364, 'max_depth': 6, 'min_child_weight': 4})
# (206.324678878508, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.6389487970818835, 'seed': 0, 'colsample_bytree': 0.8130881814744491, 'nrounds': 447, 'objective': 'reg:linear', 'learning_rate': 0.0049110623477759642, 'max_depth': 2, 'min_child_weight': 2})
# (283.47791683013793, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.015343623141486532, 'seed': 0, 'colsample_bytree': 0.5955028534021167, 'nrounds': 488, 'objective': 'reg:linear', 'learning_rate': 0.0044961474006137998, 'max_depth': 6, 'min_child_weight': 3})
# (84.661422984466256, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.22028165010211764, 'seed': 0, 'colsample_bytree': 0.7601588107745668, 'nrounds': 573, 'objective': 'reg:linear', 'learning_rate': 0.043969990214689454, 'max_depth': 2, 'min_child_weight': 1})
# (78.821188370046059, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.23168357417489052, 'seed': 0, 'colsample_bytree': 0.47895184580547556, 'nrounds': 731, 'objective': 'reg:linear', 'learning_rate': 0.014699850653090485, 'max_depth': 2, 'min_child_weight': 4})
# (83.968683659740236, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.47067083190334, 'seed': 0, 'colsample_bytree': 0.65080635004452, 'nrounds': 453, 'objective': 'reg:linear', 'learning_rate': 0.021816261585614043, 'max_depth': 8, 'min_child_weight': 3})
# (112.45943007742646, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.02879963618453435, 'seed': 0, 'colsample_bytree': 0.661245950247837, 'nrounds': 658, 'objective': 'reg:linear', 'learning_rate': 0.086605307387272304, 'max_depth': 3, 'min_child_weight': 3})
# (107.95641000888627, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.382106062070939, 'seed': 0, 'colsample_bytree': 0.17016866875691639, 'nrounds': 741, 'objective': 'reg:linear', 'learning_rate': 0.004343111187022383, 'max_depth': 1, 'min_child_weight': 1})
# (84.339488025042371, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.8196290611426057, 'seed': 0, 'colsample_bytree': 0.5343799104253045, 'nrounds': 641, 'objective': 'reg:linear', 'learning_rate': 0.015527654527090927, 'max_depth': 9, 'min_child_weight': 3})
# (113.32491645420373, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5771631443061495, 'seed': 0, 'colsample_bytree': 0.7972505212780014, 'nrounds': 707, 'objective': 'reg:linear', 'learning_rate': 0.0040077929627165328, 'max_depth': 3, 'min_child_weight': 2})
# (87.336529666671495, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5149779580648093, 'seed': 0, 'colsample_bytree': 0.7682405000162427, 'nrounds': 682, 'objective': 'reg:linear', 'learning_rate': 0.066703936804072606, 'max_depth': 3, 'min_child_weight': 4})
# (88.090327417451888, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.8175098917526868, 'seed': 0, 'colsample_bytree': 0.20389810603523043, 'nrounds': 618, 'objective': 'reg:linear', 'learning_rate': 0.052236375321141802, 'max_depth': 6, 'min_child_weight': 3})
# (103.58896808165633, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.23704303201438764, 'seed': 0, 'colsample_bytree': 0.8504630961322454, 'nrounds': 636, 'objective': 'reg:linear', 'learning_rate': 0.068235590875069321, 'max_depth': 9, 'min_child_weight': 1})
# (1528.1803295222319, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.2565803990592683, 'seed': 0, 'colsample_bytree': 0.12180213325057603, 'nrounds': 465, 'objective': 'reg:linear', 'learning_rate': 0.0021296569441426323, 'max_depth': 8, 'min_child_weight': 2})
# (89.419563023845697, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.14467563438529216, 'seed': 0, 'colsample_bytree': 0.46959988938190605, 'nrounds': 596, 'objective': 'reg:linear', 'learning_rate': 0.036475908760738585, 'max_depth': 5, 'min_child_weight': 2})
# (1060.309585858631, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.27548621733657785, 'seed': 0, 'colsample_bytree': 0.35070635606984407, 'nrounds': 604, 'objective': 'reg:linear', 'learning_rate': 0.0019585272478967021, 'max_depth': 7, 'min_child_weight': 1})
# (79.455947882071428, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.14211739920986674, 'seed': 0, 'colsample_bytree': 0.12546899773505601, 'nrounds': 422, 'objective': 'reg:linear', 'learning_rate': 0.01966561070117739, 'max_depth': 8, 'min_child_weight': 4})
# (84.623436304592857, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.6008334609920899, 'seed': 0, 'colsample_bytree': 0.8278525235891147, 'nrounds': 473, 'objective': 'reg:linear', 'learning_rate': 0.032218462767147835, 'max_depth': 5, 'min_child_weight': 4})
# (77.62227737655175, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.538016663958998, 'seed': 0, 'colsample_bytree': 0.17075060228950037, 'nrounds': 565, 'objective': 'reg:linear', 'learning_rate': 0.011385123890457234, 'max_depth': 3, 'min_child_weight': 2})
# (93.119108656317067, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.9452429970203728, 'seed': 0, 'colsample_bytree': 0.5501391030610946, 'nrounds': 744, 'objective': 'reg:linear', 'learning_rate': 0.091002159806427688, 'max_depth': 7, 'min_child_weight': 4})
# (92.008271147806099, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.029356283901966554, 'seed': 0, 'colsample_bytree': 0.9824542445236429, 'nrounds': 323, 'objective': 'reg:linear', 'learning_rate': 0.052384966001460455, 'max_depth': 8, 'min_child_weight': 4})
# (89.417808521339339, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.597230992830965, 'seed': 0, 'colsample_bytree': 0.07863286404472859, 'nrounds': 794, 'objective': 'reg:linear', 'learning_rate': 0.085194718177391326, 'max_depth': 5, 'min_child_weight': 2})
# (85.324530419372493, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5540139736138646, 'seed': 0, 'colsample_bytree': 0.6672280568676667, 'nrounds': 538, 'objective': 'reg:linear', 'learning_rate': 0.03839790078243218, 'max_depth': 5, 'min_child_weight': 4})
# (89.661005557824595, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.04309011571744889, 'seed': 0, 'colsample_bytree': 0.13784328110304195, 'nrounds': 307, 'objective': 'reg:linear', 'learning_rate': 0.019334258819929492, 'max_depth': 1, 'min_child_weight': 3})
# (299.5375487596873, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5873368705449834, 'seed': 0, 'colsample_bytree': 0.2783874325915782, 'nrounds': 423, 'objective': 'reg:linear', 'learning_rate': 0.0045629148211103233, 'max_depth': 4, 'min_child_weight': 3})
# (77.373040970163672, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.842256568916091, 'seed': 0, 'colsample_bytree': 0.8749523022017889, 'nrounds': 439, 'objective': 'reg:linear', 'learning_rate': 0.018999506973887879, 'max_depth': 3, 'min_child_weight': 2})
# (95.08571703018201, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.259799820872832, 'seed': 0, 'colsample_bytree': 0.22363315776345516, 'nrounds': 402, 'objective': 'reg:linear', 'learning_rate': 0.0081962867499104659, 'max_depth': 6, 'min_child_weight': 4})
# (79.192124826265797, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.35127225809764034, 'seed': 0, 'colsample_bytree': 0.8945595958704918, 'nrounds': 761, 'objective': 'reg:linear', 'learning_rate': 0.010870048507942563, 'max_depth': 3, 'min_child_weight': 1})
# (522.74979750287901, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.26525694951889434, 'seed': 0, 'colsample_bytree': 0.22591242163966443, 'nrounds': 708, 'objective': 'reg:linear', 'learning_rate': 0.0022460423838289592, 'max_depth': 2, 'min_child_weight': 2})
# (78.903347627046074, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.7823547734616031, 'seed': 0, 'colsample_bytree': 0.34378954398615047, 'nrounds': 303, 'objective': 'reg:linear', 'learning_rate': 0.01488177606319614, 'max_depth': 7, 'min_child_weight': 2})
# (82.407520477090245, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5755507603215639, 'seed': 0, 'colsample_bytree': 0.26150931895322227, 'nrounds': 795, 'objective': 'reg:linear', 'learning_rate': 0.011584228445412396, 'max_depth': 9, 'min_child_weight': 1})
# (929.39646187369908, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5940404054890502, 'seed': 0, 'colsample_bytree': 0.35195165442784077, 'nrounds': 704, 'objective': 'reg:linear', 'learning_rate': 0.0017751025700638438, 'max_depth': 7, 'min_child_weight': 2})
# (1054.0228012184091, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.3216896318135012, 'seed': 0, 'colsample_bytree': 0.9751808969978963, 'nrounds': 590, 'objective': 'reg:linear', 'learning_rate': 0.0020048343399811101, 'max_depth': 9, 'min_child_weight': 1})
# (100.28896639323231, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.07276723244333626, 'seed': 0, 'colsample_bytree': 0.434669959159831, 'nrounds': 694, 'objective': 'reg:linear', 'learning_rate': 0.061125241695112915, 'max_depth': 8, 'min_child_weight': 4})
# (3771.0359959053167, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.24698473485673358, 'seed': 0, 'colsample_bytree': 0.7440579277920637, 'nrounds': 432, 'objective': 'reg:linear', 'learning_rate': 0.001188256753879881, 'max_depth': 8, 'min_child_weight': 1})
# (80.939278142132608, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5283772014163104, 'seed': 0, 'colsample_bytree': 0.25149189212339673, 'nrounds': 768, 'objective': 'reg:linear', 'learning_rate': 0.028528695110647668, 'max_depth': 3, 'min_child_weight': 3})
# (88.491173517699522, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.4884567925547301, 'seed': 0, 'colsample_bytree': 0.37064421815590815, 'nrounds': 326, 'objective': 'reg:linear', 'learning_rate': 0.06726276905217711, 'max_depth': 7, 'min_child_weight': 1})
# (100.98943898785707, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.4785949143241515, 'seed': 0, 'colsample_bytree': 0.2775504241639698, 'nrounds': 761, 'objective': 'reg:linear', 'learning_rate': 0.0040588160081804527, 'max_depth': 5, 'min_child_weight': 4})
# (1274.3938556165665, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.37243128745264503, 'seed': 0, 'colsample_bytree': 0.6260453712547044, 'nrounds': 329, 'objective': 'reg:linear', 'learning_rate': 0.0032790334422894167, 'max_depth': 6, 'min_child_weight': 2})
# (321.4207066507588, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.9549956534504548, 'seed': 0, 'colsample_bytree': 0.3599870935904646, 'nrounds': 667, 'objective': 'reg:linear', 'learning_rate': 0.0028125221083213758, 'max_depth': 3, 'min_child_weight': 3})
# (84.389159523012239, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.913690311833082, 'seed': 0, 'colsample_bytree': 0.4498751525632647, 'nrounds': 460, 'objective': 'reg:linear', 'learning_rate': 0.028215844837599244, 'max_depth': 8, 'min_child_weight': 4})
# (82.301765629344729, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.6765572243500106, 'seed': 0, 'colsample_bytree': 0.1454824783243473, 'nrounds': 486, 'objective': 'reg:linear', 'learning_rate': 0.025146003822274828, 'max_depth': 7, 'min_child_weight': 2})
# (79.704902566990356, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.438752627697438, 'seed': 0, 'colsample_bytree': 0.3226352096368384, 'nrounds': 586, 'objective': 'reg:linear', 'learning_rate': 0.05543395360338918, 'max_depth': 1, 'min_child_weight': 1})
# (1321.0308154409054, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.0938616987142974, 'seed': 0, 'colsample_bytree': 0.09535842803446432, 'nrounds': 450, 'objective': 'reg:linear', 'learning_rate': 0.0023986840055389368, 'max_depth': 9, 'min_child_weight': 2})
# (78.293966455992773, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.45866627689382616, 'seed': 0, 'colsample_bytree': 0.5850270171897216, 'nrounds': 643, 'objective': 'reg:linear', 'learning_rate': 0.0084049825631306706, 'max_depth': 4, 'min_child_weight': 1})
# (77.934251122871231, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.4312402456640422, 'seed': 0, 'colsample_bytree': 0.18547736273595494, 'nrounds': 427, 'objective': 'reg:linear', 'learning_rate': 0.014944973154143363, 'max_depth': 2, 'min_child_weight': 2})
# (79.852256787983464, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.9891691069957137, 'seed': 0, 'colsample_bytree': 0.5531131142722442, 'nrounds': 562, 'objective': 'reg:linear', 'learning_rate': 0.034448688909063364, 'max_depth': 3, 'min_child_weight': 2})
# (84.473021430437228, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.789864236040683, 'seed': 0, 'colsample_bytree': 0.6946334041672984, 'nrounds': 449, 'objective': 'reg:linear', 'learning_rate': 0.081576814084864349, 'max_depth': 3, 'min_child_weight': 1})
# (817.65808092387738, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.8350655459832297, 'seed': 0, 'colsample_bytree': 0.94229198528421, 'nrounds': 761, 'objective': 'reg:linear', 'learning_rate': 0.0017297084343676, 'max_depth': 9, 'min_child_weight': 4})
# (1972.805978922609, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.9712471562568193, 'seed': 0, 'colsample_bytree': 0.5386479842471007, 'nrounds': 749, 'objective': 'reg:linear', 'learning_rate': 0.0011282204800025727, 'max_depth': 6, 'min_child_weight': 3})
# (122.96785213299042, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.2351775846271501, 'seed': 0, 'colsample_bytree': 0.45487173396810976, 'nrounds': 531, 'objective': 'reg:linear', 'learning_rate': 0.0052177123687581015, 'max_depth': 5, 'min_child_weight': 2})
# (92.126049991612248, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.30757855056386374, 'seed': 0, 'colsample_bytree': 0.35305440912252517, 'nrounds': 511, 'objective': 'reg:linear', 'learning_rate': 0.052780117116538433, 'max_depth': 8, 'min_child_weight': 4})
# (80.310982316971874, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.2222500204387106, 'seed': 0, 'colsample_bytree': 0.35160665250228534, 'nrounds': 446, 'objective': 'reg:linear', 'learning_rate': 0.026424605449707494, 'max_depth': 1, 'min_child_weight': 1})
# (258.71250471041481, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5959165313306636, 'seed': 0, 'colsample_bytree': 0.9732725554654782, 'nrounds': 525, 'objective': 'reg:linear', 'learning_rate': 0.0038550240650463584, 'max_depth': 3, 'min_child_weight': 2})
# (3048.5824423571103, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5709820606492254, 'seed': 0, 'colsample_bytree': 0.7165830114635354, 'nrounds': 512, 'objective': 'reg:linear', 'learning_rate': 0.00121227675912905, 'max_depth': 4, 'min_child_weight': 4})
# (2765.4002617409956, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.732980395021274, 'seed': 0, 'colsample_bytree': 0.6028353132943826, 'nrounds': 662, 'objective': 'reg:linear', 'learning_rate': 0.0010165806496259505, 'max_depth': 1, 'min_child_weight': 3})
# (79.060940047652394, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.3636836881618973, 'seed': 0, 'colsample_bytree': 0.12360533125988019, 'nrounds': 542, 'objective': 'reg:linear', 'learning_rate': 0.031157516914475634, 'max_depth': 3, 'min_child_weight': 4})
# (1565.6590376385454, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.028398274785736498, 'seed': 0, 'colsample_bytree': 0.13898691057662632, 'nrounds': 584, 'objective': 'reg:linear', 'learning_rate': 0.0017236249579841831, 'max_depth': 4, 'min_child_weight': 4})
# (1248.3681010467833, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.14973102459938464, 'seed': 0, 'colsample_bytree': 0.44440593026816766, 'nrounds': 564, 'objective': 'reg:linear', 'learning_rate': 0.0019487599708608552, 'max_depth': 7, 'min_child_weight': 2})
# (78.330916205929569, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.8088314271608807, 'seed': 0, 'colsample_bytree': 0.8216840897010191, 'nrounds': 705, 'objective': 'reg:linear', 'learning_rate': 0.019307002318699897, 'max_depth': 1, 'min_child_weight': 4})
# (268.53045148848281, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5814467582613286, 'seed': 0, 'colsample_bytree': 0.6699346072216629, 'nrounds': 586, 'objective': 'reg:linear', 'learning_rate': 0.0034158880869149294, 'max_depth': 6, 'min_child_weight': 4})
# (78.836293402077132, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.8612174118478082, 'seed': 0, 'colsample_bytree': 0.08271083246625455, 'nrounds': 547, 'objective': 'reg:linear', 'learning_rate': 0.013511918749980674, 'max_depth': 3, 'min_child_weight': 4})
# (748.50633015980827, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5801995733989552, 'seed': 0, 'colsample_bytree': 0.23178623665344053, 'nrounds': 564, 'objective': 'reg:linear', 'learning_rate': 0.0024344516826413235, 'max_depth': 3, 'min_child_weight': 2})
# (83.335406437896282, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.42271541092594256, 'seed': 0, 'colsample_bytree': 0.2999525294516458, 'nrounds': 701, 'objective': 'reg:linear', 'learning_rate': 0.015177303215149087, 'max_depth': 7, 'min_child_weight': 1})
# (91.085999457905942, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.12127578032724473, 'seed': 0, 'colsample_bytree': 0.27202308165267475, 'nrounds': 770, 'objective': 'reg:linear', 'learning_rate': 0.0046136657216827052, 'max_depth': 7, 'min_child_weight': 4})
# (190.05008550532577, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.8616213509821974, 'seed': 0, 'colsample_bytree': 0.6762927681021313, 'nrounds': 674, 'objective': 'reg:linear', 'learning_rate': 0.0033525421118022376, 'max_depth': 4, 'min_child_weight': 4})
# (5251.0254942778774, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.669813523219516, 'seed': 0, 'colsample_bytree': 0.4073077628086951, 'nrounds': 322, 'objective': 'reg:linear', 'learning_rate': 0.0010619788333357243, 'max_depth': 9, 'min_child_weight': 4})
# (283.66067250106335, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5048842869481087, 'seed': 0, 'colsample_bytree': 0.0927189856872103, 'nrounds': 720, 'objective': 'reg:linear', 'learning_rate': 0.0027811151978209096, 'max_depth': 7, 'min_child_weight': 3})
# (255.68099795316036, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.27802844688883077, 'seed': 0, 'colsample_bytree': 0.8481143720877807, 'nrounds': 744, 'objective': 'reg:linear', 'learning_rate': 0.002765210101179443, 'max_depth': 7, 'min_child_weight': 1})
# (80.94805366311796, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.20453034399827696, 'seed': 0, 'colsample_bytree': 0.6459674214749862, 'nrounds': 656, 'objective': 'reg:linear', 'learning_rate': 0.02341173226486408, 'max_depth': 2, 'min_child_weight': 1})
# (82.233654947704451, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.49658476992725714, 'seed': 0, 'colsample_bytree': 0.9823930556875002, 'nrounds': 351, 'objective': 'reg:linear', 'learning_rate': 0.021070295105162867, 'max_depth': 9, 'min_child_weight': 4})
# (96.070865227609232, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.9660533556957903, 'seed': 0, 'colsample_bytree': 0.0216191722703781, 'nrounds': 314, 'objective': 'reg:linear', 'learning_rate': 0.016418865816377887, 'max_depth': 4, 'min_child_weight': 1})
# (94.76091128834743, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5405169252451357, 'seed': 0, 'colsample_bytree': 0.7590054394162926, 'nrounds': 620, 'objective': 'reg:linear', 'learning_rate': 0.062838203484600896, 'max_depth': 6, 'min_child_weight': 3})
# (97.513980681147189, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.6344213269518334, 'seed': 0, 'colsample_bytree': 0.3440960551209735, 'nrounds': 670, 'objective': 'reg:linear', 'learning_rate': 0.0047716190450850489, 'max_depth': 9, 'min_child_weight': 1})
# (81.40017698688132, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5196302648727831, 'seed': 0, 'colsample_bytree': 0.7796243856661146, 'nrounds': 562, 'objective': 'reg:linear', 'learning_rate': 0.023410717442940834, 'max_depth': 4, 'min_child_weight': 3})
# (1648.8197812330011, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.492922665236196, 'seed': 0, 'colsample_bytree': 0.8928523770391394, 'nrounds': 570, 'objective': 'reg:linear', 'learning_rate': 0.0016510479569861766, 'max_depth': 8, 'min_child_weight': 2})
# (83.322068029155986, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.06252678419343219, 'seed': 0, 'colsample_bytree': 0.11405094839681341, 'nrounds': 782, 'objective': 'reg:linear', 'learning_rate': 0.017229133894756853, 'max_depth': 1, 'min_child_weight': 2})
# (130.39679555790025, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.7761335918428235, 'seed': 0, 'colsample_bytree': 0.5198261606507779, 'nrounds': 350, 'objective': 'reg:linear', 'learning_rate': 0.0075956618838383602, 'max_depth': 9, 'min_child_weight': 4})
# (97.449161770705814, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.8387085762974662, 'seed': 0, 'colsample_bytree': 0.03522124355354364, 'nrounds': 489, 'objective': 'reg:linear', 'learning_rate': 0.010578909649113694, 'max_depth': 1, 'min_child_weight': 1})
# (87.472823440435093, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.40049026614165667, 'seed': 0, 'colsample_bytree': 0.9278991395309868, 'nrounds': 735, 'objective': 'reg:linear', 'learning_rate': 0.018510135311523266, 'max_depth': 9, 'min_child_weight': 3})
# (80.451862237524892, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.11671151254191127, 'seed': 0, 'colsample_bytree': 0.23858796295452536, 'nrounds': 772, 'objective': 'reg:linear', 'learning_rate': 0.010400138808210377, 'max_depth': 9, 'min_child_weight': 1})
# (974.18707819232191, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.8565118491467563, 'seed': 0, 'colsample_bytree': 0.4071381754567519, 'nrounds': 747, 'objective': 'reg:linear', 'learning_rate': 0.0016353149633689128, 'max_depth': 4, 'min_child_weight': 3})
# (95.670890267198828, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.14139393408081313, 'seed': 0, 'colsample_bytree': 0.3274819269356226, 'nrounds': 414, 'objective': 'reg:linear', 'learning_rate': 0.0088199992836214495, 'max_depth': 1, 'min_child_weight': 3})
# (78.456942209479308, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.5951708483833456, 'seed': 0, 'colsample_bytree': 0.13936584947392758, 'nrounds': 324, 'objective': 'reg:linear', 'learning_rate': 0.031867654887912787, 'max_depth': 4, 'min_child_weight': 3})
# (80.018820744170711, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.5790044791465132, 'seed': 0, 'colsample_bytree': 0.7224571053644021, 'nrounds': 726, 'objective': 'reg:linear', 'learning_rate': 0.068639155263319387, 'max_depth': 1, 'min_child_weight': 3})
# (78.63671615875576, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.9488896694457174, 'seed': 0, 'colsample_bytree': 0.21634812878653922, 'nrounds': 613, 'objective': 'reg:linear', 'learning_rate': 0.059538009451802071, 'max_depth': 1, 'min_child_weight': 1})
# (1805.8390811077427, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.33716368971988186, 'seed': 0, 'colsample_bytree': 0.6980521783291023, 'nrounds': 673, 'objective': 'reg:linear', 'learning_rate': 0.0013301773104422881, 'max_depth': 7, 'min_child_weight': 1})
# (88.878988583688567, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.8130551958861945, 'seed': 0, 'colsample_bytree': 0.1197152902500213, 'nrounds': 758, 'objective': 'reg:linear', 'learning_rate': 0.095095002933292871, 'max_depth': 4, 'min_child_weight': 4})
# (145.15523239876299, 76.682275254253497, {'num_parallel_tree': 1, 'subsample': 0.036887789909213674, 'seed': 0, 'colsample_bytree': 0.3197222653183382, 'nrounds': 721, 'objective': 'reg:linear', 'learning_rate': 0.0037626502466446268, 'max_depth': 2, 'min_child_weight': 2})
# (80.157258707619235, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.13810034357879697, 'seed': 0, 'colsample_bytree': 0.5292181590231584, 'nrounds': 759, 'objective': 'reg:linear', 'learning_rate': 0.0059093594839485231, 'max_depth': 6, 'min_child_weight': 2})
# (83.864917156311634, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.08510544814872638, 'seed': 0, 'colsample_bytree': 0.7983625261434547, 'nrounds': 416, 'objective': 'reg:linear', 'learning_rate': 0.042238973106750954, 'max_depth': 1, 'min_child_weight': 3})
# (77.900380909819333, 76.682275254253497, {'num_parallel_tree': 2, 'subsample': 0.4650427741733202, 'seed': 0, 'colsample_bytree': 0.17732124255964485, 'nrounds': 730, 'objective': 'reg:linear', 'learning_rate': 0.019924149611484865, 'max_depth': 2, 'min_child_weight': 1})

# %% [markdown]
# # Second Layer

# %%
xgb_data = pickle.load(open('xgb.p','rb'))
et_data = pickle.load(open('et.p','rb'))
rf_data = pickle.load(open('rf.p','rb'))
L = 30
N = 3
X_val_bar = np.zeros([2105, L*N])
X_test_bar = np.zeros([4209, L*N])
id_col = (i for i in range(L*N)) 
for dt in sorted(et_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])

for dt in sorted(rf_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])
for dt in sorted(xgb_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])

# %%
def get_oof_2nd_layer(clf,X_train,y_train, X_val):
    ntrain = X_train.shape[0]
    nval = X_val.shape[0]
    oof_train = np.zeros((ntrain,))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))
    kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)
    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]
        clf.train(X_tr, y_tr)
        oof_train[test_index] = clf.predict(X_te)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1)

def turing_2nd_layer(clf,N):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_val, oof_test = get_oof_2nd_layer(model, X_val_bar, y_val, X_test_bar)
        err = mean_squared_error(y_val, oof_val)
        if best_err > err:
            best_err = err
            best_para = params
            best_y = oof_test
        print(err,best_err, params)
    #pickle.dump(best_para,open("2nd_layer_para.p",'wb'))
    return best_y

# %%
best_y = turing_2nd_layer(RandomForestRegressor, 40)
# Out:
# (63.237000186570711, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 236, 'random_state': 0, 'max_features': 0.05511468941217113, 'max_depth': 6})
# (63.809119275198931, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 274, 'random_state': 0, 'max_features': 0.3270563169499595, 'max_depth': 7})
# (63.674965301769006, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 447, 'random_state': 0, 'max_features': 0.06155342550859197, 'max_depth': 7})
# (63.328195045889267, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 716, 'random_state': 0, 'max_features': 0.5476909021001328, 'max_depth': 3})
# (63.956392400755909, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 461, 'random_state': 0, 'max_features': 0.9548000436047506, 'max_depth': 2})
# (64.114115347578846, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 519, 'random_state': 0, 'max_features': 0.2837422727955775, 'max_depth': 8})
# (63.604484164941503, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 460, 'random_state': 0, 'max_features': 0.6273659164717464, 'max_depth': 6})
# (65.360916614276846, 63.237000186570711, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 183, 'random_state': 0, 'max_features': 0.5538646520404521, 'max_depth': 8})
# (63.160709150822314, 63.160709150822314, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 891, 'random_state': 0, 'max_features': 0.7620166497667641, 'max_depth': 3})
# (63.117264263088217, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 206, 'random_state': 0, 'max_features': 0.864340845159004, 'max_depth': 3})
# (65.189186281095246, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 294, 'random_state': 0, 'max_features': 0.9962367610517318, 'max_depth': 8})
# (63.341481283024912, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 685, 'random_state': 0, 'max_features': 0.5779911378873508, 'max_depth': 3})
# (64.445260815099218, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 400, 'random_state': 0, 'max_features': 0.1751432513128588, 'max_depth': 8})
# (63.187427827543736, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 143, 'random_state': 0, 'max_features': 0.7242336094302185, 'max_depth': 3})
# (82.160275143466421, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 360, 'random_state': 0, 'max_features': 0.3952004039744341, 'max_depth': 1})
# (63.385072318990112, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 851, 'random_state': 0, 'max_features': 0.018384368604456396, 'max_depth': 7})
# (63.195222886638732, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 380, 'random_state': 0, 'max_features': 0.5454249312307253, 'max_depth': 4})
# (64.22399325140502, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 649, 'random_state': 0, 'max_features': 0.2888137406652657, 'max_depth': 8})
# (63.526332205895962, 63.117264263088217, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 760, 'random_state': 0, 'max_features': 0.9326919218393651, 'max_depth': 5})
# (63.067232279743017, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 492, 'random_state': 0, 'max_features': 0.42688308258459096, 'max_depth': 4})
# (63.97262587440558, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 344, 'random_state': 0, 'max_features': 0.7971285340631049, 'max_depth': 2})
# (63.891298236541815, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 484, 'random_state': 0, 'max_features': 0.3073150925471652, 'max_depth': 7})
# (63.974410679287814, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 79, 'random_state': 0, 'max_features': 0.7594560975413865, 'max_depth': 2})
# (64.599375964765287, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 394, 'random_state': 0, 'max_features': 0.7419847788103581, 'max_depth': 8})
# (63.606037562165739, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 217, 'random_state': 0, 'max_features': 0.15223134412949146, 'max_depth': 7})
# (64.789760763858723, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 250, 'random_state': 0, 'max_features': 0.6483689178164354, 'max_depth': 9})
# (63.723135001551135, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 307, 'random_state': 0, 'max_features': 0.04399907185534842, 'max_depth': 8})
# (63.691665603516753, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 668, 'random_state': 0, 'max_features': 0.13736606849565627, 'max_depth': 6})
# (64.831357585353913, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 93, 'random_state': 0, 'max_features': 0.7419090925301736, 'max_depth': 8})
# (82.019507083464717, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 127, 'random_state': 0, 'max_features': 0.7518494180210122, 'max_depth': 1})
# (64.721010365910331, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 660, 'random_state': 0, 'max_features': 0.71640280487622, 'max_depth': 7})
# (63.910896201889322, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 812, 'random_state': 0, 'max_features': 0.4874207639533452, 'max_depth': 2})
# (63.13757171779185, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 447, 'random_state': 0, 'max_features': 0.7126409091242768, 'max_depth': 3})
# (63.296626341088668, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 71, 'random_state': 0, 'max_features': 0.1224060692165006, 'max_depth': 4})
# (65.090982559912931, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 809, 'random_state': 0, 'max_features': 0.7080080176863051, 'max_depth': 9})
# (81.976474900688117, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 845, 'random_state': 0, 'max_features': 0.8564070006267488, 'max_depth': 1})
# (63.883263736568182, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 201, 'random_state': 0, 'max_features': 0.9488176390299491, 'max_depth': 2})
# (82.414760348686059, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 273, 'random_state': 0, 'max_features': 0.013060706133731819, 'max_depth': 1})
# (63.305649017874622, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 51, 'random_state': 0, 'max_features': 0.11026056924740571, 'max_depth': 4})
# (63.910856099020663, 63.067232279743017, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 317, 'random_state': 0, 'max_features': 0.8875530605389258, 'max_depth': 2})

# %%
submission = pd.read_csv(SUBMISSION_FILE)
submission.iloc[:, 1] = best_y
submission.to_csv('stacking_sub.csv', index=None)
