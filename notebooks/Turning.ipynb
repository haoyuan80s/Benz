# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import pickle
from scipy.stats import randint as sp_randint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor

# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
# Out:
# /home/haoyuan/assignment1/.env/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def data_with_val():
    print('generating data......')
    # read datasets
    train_total = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

    # Shuffle data
    np.random.seed(0)
    l = [x for x in range(4209)]
    np.random.shuffle(l)
    train_total = train_total.iloc[l]

    # split data
    ratio = 0.8
    threshold = int(ratio*4209)
    X_train = train_total.iloc[range(threshold)] 
    val = train_total.iloc[range(threshold, 4209)]
    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)
    y_val = val['y']
    X_val = val.drop('y', axis = 1)

    # process type
    for c in train_total.columns:
        if train_total[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(train_total[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_val[c] = lbl.transform(list(X_val[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    print('Shape X_val:', X_val.shape )
    return X_train, y_train, X_val, y_val, X_test

def data():
    print('generating data......')
    # read datasets
    X_train = pd.read_csv('../data/train.csv') ## Shape train: (4209, 378)
    X_test = pd.read_csv('../data/test.csv') ## Shape test: (4209, 377)

#     # Shuffle data
#     l = [x for x in range(4209)]
#     np.random.seed(0)
#     np.random.shuffle(l)
#     X_train = X_train.iloc[l]

    y_train = X_train['y']
    X_train = X_train.drop('y', axis = 1)

    # process type
    for c in X_train.columns:
        if X_train[c].dtype == 'object':
            lbl = LabelEncoder() 
            lbl.fit(list(X_train[c].values) + list(X_test[c].values)) 
            X_train[c] = lbl.transform(list(X_train[c].values))
            X_test[c] = lbl.transform(list(X_test[c].values))

    # shape        
    print('Shape X_train:', X_train.shape)
    print('Shape X_test:', X_test.shape)
    return X_train, y_train, X_test

# %%
# X_train,y_train, X_val,y_val, X_test = data_with_val()
X_train,y_train, X_test = data()
X_val,y_val = X_train[:],y_train[:]
# Out:
# generating data......
# ('Shape X_train:', (4209, 377))
# ('Shape X_test:', (4209, 377))

# %%
# Gloable data

ID = 'ID'
TARGET = 'y'
NFOLDS = 4
SEED = 1
NROWS = None
DATA_DIR = "../data"
SUBMISSION_FILE = "{0}/sample_submission.csv".format(DATA_DIR)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)

SEED = 0
ntrain, D = X_train.shape
nval = X_val.shape[0]
ntest = X_test.shape[0]
NFOLDS = 4

kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, X_train, y_train):
        self.clf.fit(X_train, y_train)

    def predict(self, X):
        return self.clf.predict(X)
    

class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        params = params.copy() # creat a local version of params
        self.nrounds = params.pop('nrounds', 250)

    def train(self, X_train, y_train):
        dtrain = xgb.DMatrix(X_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, X):
        return self.gbdt.predict(xgb.DMatrix(X))
    

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))

    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]

        clf.train(X_tr, y_tr)

        oof_train[test_index] = clf.predict(X_te)
        oof_test_skf[i, :] = clf.predict(X_test)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_test[:] = oof_test_skf.mean(axis=0)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
def turing_xgb(N):
    best_err = 100000000
    data = []
    for _ in range(N):
        params = {
            'colsample_bytree': np.random.uniform(0.01,1),
            'subsample': np.random.uniform(0.01,1),
            'learning_rate': np.exp(np.random.uniform(np.log(0.001),np.log(0.1))),
            'objective': 'reg:linear',
            'max_depth': int(np.random.uniform(1,10)),
            'num_parallel_tree': int(np.random.uniform(1,3)),
            'min_child_weight': int(np.random.uniform(1,5)),
            'nrounds': int(np.random.uniform(300,800))
        }
        model = XgbWrapper(seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err, oof_train, oof_val, oof_test)]

    pickle.dump(data,open("xgb.p",'wb'))    
    
def turing(clf,N,name):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_train, oof_val ,oof_test = get_oof(model)
        err = mean_squared_error(y_train, oof_train)
        if best_err > err:
            best_err = err
            best_para = params
        print(err,best_err, params)
        data += [(params,err,oof_train, oof_val, oof_test)]

    pickle.dump(data,open("{}.p".format(name),'wb'))

# %%
N = 100
turing(RandomForestRegressor,N,'rf')
turing(ExtraTreesRegressor,N,'et')
turing_xgb(N)
# Out:
# (83.071173415703754, 83.071173415703754, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 76, 'random_state': 0, 'max_features': 0.21046788327613053, 'max_depth': 2})
# (70.329537961826233, 70.329537961826233, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 462, 'random_state': 0, 'max_features': 0.20097756507283196, 'max_depth': 5})
# (69.45344181350417, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 508, 'random_state': 0, 'max_features': 0.8420608459992439, 'max_depth': 5})
# (71.817402076655512, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 505, 'random_state': 0, 'max_features': 0.1755284239524712, 'max_depth': 4})
# (69.605289324317454, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 563, 'random_state': 0, 'max_features': 0.5569383955539077, 'max_depth': 4})
# (71.640703543773384, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 2, 'random_state': 0, 'max_features': 0.9960542617507644, 'max_depth': 4})
# (70.255255032633727, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 700, 'random_state': 0, 'max_features': 0.6253080363461867, 'max_depth': 8})
# (100.17882498885513, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 80, 'random_state': 0, 'max_features': 0.425278799072389, 'max_depth': 1})
# (69.727407430468531, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 543, 'random_state': 0, 'max_features': 0.41465426858661, 'max_depth': 6})
# (69.718090452796943, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 876, 'random_state': 0, 'max_features': 0.3193545929211553, 'max_depth': 6})
# (69.475453085713852, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 199, 'random_state': 0, 'max_features': 0.9715024944869979, 'max_depth': 5})
# (69.632764691443057, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 595, 'random_state': 0, 'max_features': 0.7332424524629944, 'max_depth': 6})
# (76.894574050059902, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 504, 'random_state': 0, 'max_features': 0.9186487830518961, 'max_depth': 2})
# (70.494029972492939, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 16, 'random_state': 0, 'max_features': 0.23369815818021625, 'max_depth': 7})
# (69.595752501183725, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 317, 'random_state': 0, 'max_features': 0.366104716895642, 'max_depth': 6})
# (100.43086009910782, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 702, 'random_state': 0, 'max_features': 0.540018254360793, 'max_depth': 1})
# (70.273486815320794, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 421, 'random_state': 0, 'max_features': 0.7673214930533067, 'max_depth': 8})
# (101.78212368457204, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 83, 'random_state': 0, 'max_features': 0.8028691968604125, 'max_depth': 1})
# (70.078582301249568, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 716, 'random_state': 0, 'max_features': 0.785335092867197, 'max_depth': 3})
# (102.53417729576951, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 673, 'random_state': 0, 'max_features': 0.2577291177011294, 'max_depth': 1})
# (97.696748897936885, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 477, 'random_state': 0, 'max_features': 0.015213006763168124, 'max_depth': 7})
# (70.10167442454464, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 803, 'random_state': 0, 'max_features': 0.25484625332051974, 'max_depth': 4})
# (77.016175982557584, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 125, 'random_state': 0, 'max_features': 0.42173028710509847, 'max_depth': 2})
# (71.298851030152079, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 103, 'random_state': 0, 'max_features': 0.1416583679220998, 'max_depth': 5})
# (100.73882358876979, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 509, 'random_state': 0, 'max_features': 0.5801392411658174, 'max_depth': 1})
# (115.01134954512082, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 354, 'random_state': 0, 'max_features': 0.1052938765210763, 'max_depth': 1})
# (75.844175408372905, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 208, 'random_state': 0, 'max_features': 0.1514107072627553, 'max_depth': 3})
# (69.787540831884115, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 46, 'random_state': 0, 'max_features': 0.23934639837681718, 'max_depth': 6})
# (69.823978683071431, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 130, 'random_state': 0, 'max_features': 0.37200939907280295, 'max_depth': 4})
# (70.279118650228654, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 615, 'random_state': 0, 'max_features': 0.19314155647456638, 'max_depth': 5})
# (71.166473923863663, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 125, 'random_state': 0, 'max_features': 0.8366250751040216, 'max_depth': 9})
# (71.773982629739294, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 325, 'random_state': 0, 'max_features': 0.17867657858713484, 'max_depth': 4})
# (70.739642283580736, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 431, 'random_state': 0, 'max_features': 0.16675773295119578, 'max_depth': 5})
# (69.992062608371384, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 491, 'random_state': 0, 'max_features': 0.7244107125532299, 'max_depth': 7})
# (70.385492464261006, 69.45344181350417, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 493, 'random_state': 0, 'max_features': 0.43977847039095685, 'max_depth': 3})
# (69.451316495568491, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 668, 'random_state': 0, 'max_features': 0.7788019460398575, 'max_depth': 5})
# (73.059300327988424, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 780, 'random_state': 0, 'max_features': 0.14450265023555953, 'max_depth': 4})
# (69.865371575855804, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 675, 'random_state': 0, 'max_features': 0.30318046016892775, 'max_depth': 4})
# (69.937115131740782, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 706, 'random_state': 0, 'max_features': 0.4523290061665505, 'max_depth': 7})
# (101.29942593185895, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 584, 'random_state': 0, 'max_features': 0.6610463498948679, 'max_depth': 1})
# (73.13294496685306, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 472, 'random_state': 0, 'max_features': 0.05916565385947026, 'max_depth': 8})
# (93.89354644164635, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 728, 'random_state': 0, 'max_features': 0.09744183684557288, 'max_depth': 2})
# (69.726592544408163, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 591, 'random_state': 0, 'max_features': 0.9683442734201672, 'max_depth': 4})
# (70.107572700756833, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 834, 'random_state': 0, 'max_features': 0.2844817280408181, 'max_depth': 4})
# (70.43956336652748, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 706, 'random_state': 0, 'max_features': 0.5627703841125544, 'max_depth': 9})
# (101.2208762086811, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 583, 'random_state': 0, 'max_features': 0.6460565765871851, 'max_depth': 1})
# (70.265064350656132, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 27, 'random_state': 0, 'max_features': 0.42363727538670143, 'max_depth': 7})
# (69.54095753492274, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 847, 'random_state': 0, 'max_features': 0.8841813303166449, 'max_depth': 5})
# (70.57151522589939, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 469, 'random_state': 0, 'max_features': 0.17058414810449474, 'max_depth': 5})
# (121.8740595423303, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 375, 'random_state': 0, 'max_features': 0.059219229162967894, 'max_depth': 1})
# (104.52114703430085, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 811, 'random_state': 0, 'max_features': 0.21892755753410825, 'max_depth': 1})
# (77.921633663667961, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 228, 'random_state': 0, 'max_features': 0.3925977600912791, 'max_depth': 2})
# (70.758181755909547, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 414, 'random_state': 0, 'max_features': 0.846186304917668, 'max_depth': 7})
# (137.59915749910945, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 402, 'random_state': 0, 'max_features': 0.020888513065447954, 'max_depth': 1})
# (71.000091033958711, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 228, 'random_state': 0, 'max_features': 0.9310049349221097, 'max_depth': 9})
# (69.964557835604296, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 277, 'random_state': 0, 'max_features': 0.31052617872416827, 'max_depth': 4})
# (70.105510988362354, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 98, 'random_state': 0, 'max_features': 0.8626758837766629, 'max_depth': 7})
# (105.21599756924287, 69.451316495568491, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 622, 'random_state': 0, 'max_features': 0.2102248796055129, 'max_depth': 1})
# (69.415633224295249, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 92, 'random_state': 0, 'max_features': 0.3835139990947276, 'max_depth': 5})
# (75.80865879079461, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 535, 'random_state': 0, 'max_features': 0.6554326827168812, 'max_depth': 2})
# (69.99531278509788, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 658, 'random_state': 0, 'max_features': 0.23447879901111862, 'max_depth': 7})
# (70.119347579641769, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 662, 'random_state': 0, 'max_features': 0.6683895810959127, 'max_depth': 6})
# (70.020940930554673, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 612, 'random_state': 0, 'max_features': 0.8816230903475609, 'max_depth': 7})
# (76.863600447195594, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 667, 'random_state': 0, 'max_features': 0.9219205057007478, 'max_depth': 2})
# (71.482344996083626, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 446, 'random_state': 0, 'max_features': 0.11123454924730235, 'max_depth': 6})
# (76.298644195968876, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 448, 'random_state': 0, 'max_features': 0.8408569857731867, 'max_depth': 2})
# (75.954275666758051, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 241, 'random_state': 0, 'max_features': 0.5826060789961868, 'max_depth': 2})
# (71.217645038951815, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 754, 'random_state': 0, 'max_features': 0.20168734129122212, 'max_depth': 4})
# (79.143686349918468, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 532, 'random_state': 0, 'max_features': 0.03373537430809022, 'max_depth': 8})
# (70.578670247145325, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 854, 'random_state': 0, 'max_features': 0.6532097228786969, 'max_depth': 9})
# (70.747849297875774, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 24, 'random_state': 0, 'max_features': 0.9494215222424817, 'max_depth': 8})
# (70.085793567621849, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 777, 'random_state': 0, 'max_features': 0.345428986156669, 'max_depth': 7})
# (69.756064188013795, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 860, 'random_state': 0, 'max_features': 0.2770216475739928, 'max_depth': 6})
# (70.204644180393942, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 577, 'random_state': 0, 'max_features': 0.6944801146885968, 'max_depth': 8})
# (81.073137674706643, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 5, 'random_state': 0, 'max_features': 0.35384753637952304, 'max_depth': 2})
# (83.909129862227843, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 820, 'random_state': 0, 'max_features': 0.05582887484727776, 'max_depth': 4})
# (69.775768965174876, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 873, 'random_state': 0, 'max_features': 0.8973012561985988, 'max_depth': 6})
# (70.754697277989933, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 77, 'random_state': 0, 'max_features': 0.8583427306881396, 'max_depth': 9})
# (79.168578621775495, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 228, 'random_state': 0, 'max_features': 0.034909201508243594, 'max_depth': 7})
# (70.922153023872141, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 221, 'random_state': 0, 'max_features': 0.6475333701667894, 'max_depth': 9})
# (78.847889513548253, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 615, 'random_state': 0, 'max_features': 0.32980160433325867, 'max_depth': 2})
# (88.022323160624239, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 426, 'random_state': 0, 'max_features': 0.1419517668733493, 'max_depth': 2})
# (69.576035568293463, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 665, 'random_state': 0, 'max_features': 0.949043054041473, 'max_depth': 5})
# (69.468410987387273, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 752, 'random_state': 0, 'max_features': 0.7800740588514186, 'max_depth': 5})
# (70.654990102281857, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 612, 'random_state': 0, 'max_features': 0.12561361178895647, 'max_depth': 7})
# (69.819881183167638, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 601, 'random_state': 0, 'max_features': 0.34587896794160544, 'max_depth': 4})
# (71.808845895977399, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 398, 'random_state': 0, 'max_features': 0.9117432880227275, 'max_depth': 9})
# (69.803782889708216, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 34, 'random_state': 0, 'max_features': 0.3706383669541437, 'max_depth': 5})
# (69.568831920009345, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 853, 'random_state': 0, 'max_features': 0.7999809660943069, 'max_depth': 4})
# (70.086159614795889, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 42, 'random_state': 0, 'max_features': 0.4959318666422653, 'max_depth': 7})
# (76.881838991095819, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 417, 'random_state': 0, 'max_features': 0.9267807672374572, 'max_depth': 2})
# (70.833849985189389, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 121, 'random_state': 0, 'max_features': 0.5637872197037286, 'max_depth': 9})
# (70.832957315340437, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 21, 'random_state': 0, 'max_features': 0.4400806241395541, 'max_depth': 3})
# (69.64007064654885, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 404, 'random_state': 0, 'max_features': 0.9236007640572057, 'max_depth': 4})
# (71.604334616193654, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 17, 'random_state': 0, 'max_features': 0.15968039772299697, 'max_depth': 9})
# (70.048636021862123, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 129, 'random_state': 0, 'max_features': 0.17144096471721168, 'max_depth': 7})
# (70.470561047139, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 885, 'random_state': 0, 'max_features': 0.7470998843061444, 'max_depth': 8})
# (70.825386373216844, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 25, 'random_state': 0, 'max_features': 0.46167768237378587, 'max_depth': 8})
# (128.86305531527725, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 850, 'random_state': 0, 'max_features': 0.03981987913057223, 'max_depth': 1})
# (70.102505686334325, 69.415633224295249, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 613, 'random_state': 0, 'max_features': 0.36226128511440714, 'max_depth': 8})
# (70.227739640427899, 70.227739640427899, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 537, 'random_state': 0, 'max_features': 0.8282202404592232, 'max_depth': 6})
# (70.045178416756457, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 427, 'random_state': 0, 'max_features': 0.3161923143133473, 'max_depth': 6})
# (79.681630288942003, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 112, 'random_state': 0, 'max_features': 0.8734203916439698, 'max_depth': 2})
# (70.898326743517359, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 262, 'random_state': 0, 'max_features': 0.21994386859966603, 'max_depth': 9})
# (106.18563601477608, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 100, 'random_state': 0, 'max_features': 0.1978427854377085, 'max_depth': 1})
# (100.64940465760375, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 348, 'random_state': 0, 'max_features': 0.5521131172661818, 'max_depth': 1})
# (70.107612001041574, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 364, 'random_state': 0, 'max_features': 0.5092564936751792, 'max_depth': 3})
# (73.80474279629756, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 165, 'random_state': 0, 'max_features': 0.8789009680517831, 'max_depth': 8})
# (71.071238890649838, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 346, 'random_state': 0, 'max_features': 0.7809693193214942, 'max_depth': 7})
# (102.12880288046257, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 8, 'random_state': 0, 'max_features': 0.8599176556478524, 'max_depth': 1})
# (76.30591239964167, 70.045178416756457, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 825, 'random_state': 0, 'max_features': 0.5604807685628093, 'max_depth': 2})
# (70.003522646825843, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 251, 'random_state': 0, 'max_features': 0.6769604280266952, 'max_depth': 6})
# (71.408100987594025, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 492, 'random_state': 0, 'max_features': 0.8309317257627151, 'max_depth': 9})
# (85.384664072048537, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 683, 'random_state': 0, 'max_features': 0.16858572716008371, 'max_depth': 2})
# (70.95856703629245, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 81, 'random_state': 0, 'max_features': 0.6588355015359504, 'max_depth': 9})
# (76.815386681558763, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 59, 'random_state': 0, 'max_features': 0.6351411951817905, 'max_depth': 2})
# (70.139820738181498, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 219, 'random_state': 0, 'max_features': 0.20815965524381655, 'max_depth': 6})
# (72.879831290480709, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 369, 'random_state': 0, 'max_features': 0.07237838326054101, 'max_depth': 7})
# (70.767866313201594, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 543, 'random_state': 0, 'max_features': 0.9395932614857622, 'max_depth': 7})
# (73.722059947758794, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 835, 'random_state': 0, 'max_features': 0.8321137567455703, 'max_depth': 8})
# (95.942963069998839, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 272, 'random_state': 0, 'max_features': 0.010996767592372194, 'max_depth': 9})
# (70.343524697540246, 70.003522646825843, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 763, 'random_state': 0, 'max_features': 0.38860013740285426, 'max_depth': 7})
# (69.785351949093595, 69.785351949093595, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 380, 'random_state': 0, 'max_features': 0.31516739129177296, 'max_depth': 6})
# (69.595872073691353, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 705, 'random_state': 0, 'max_features': 0.43534146540149926, 'max_depth': 4})
# (70.083612446947669, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 791, 'random_state': 0, 'max_features': 0.5716983099486529, 'max_depth': 3})
# (86.074577505471964, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 760, 'random_state': 0, 'max_features': 0.1593568815186077, 'max_depth': 2})
# (70.499416382367031, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 455, 'random_state': 0, 'max_features': 0.34427469717211723, 'max_depth': 8})
# (69.729105345476199, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 768, 'random_state': 0, 'max_features': 0.49747765418043305, 'max_depth': 4})
# (70.520737062418704, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 704, 'random_state': 0, 'max_features': 0.5708461705772477, 'max_depth': 8})
# (70.122328976843491, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 814, 'random_state': 0, 'max_features': 0.5972551173868845, 'max_depth': 7})
# (70.318407548803165, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 835, 'random_state': 0, 'max_features': 0.9083978795469754, 'max_depth': 3})
# (75.312774815334265, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 455, 'random_state': 0, 'max_features': 0.991563613068146, 'max_depth': 9})
# (70.152505349621123, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 517, 'random_state': 0, 'max_features': 0.7710778380677349, 'max_depth': 6})
# (79.491223432417669, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 842, 'random_state': 0, 'max_features': 0.05767687732489576, 'max_depth': 5})
# (69.741513753945213, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 690, 'random_state': 0, 'max_features': 0.6461932904991359, 'max_depth': 5})
# (69.603800108111159, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 633, 'random_state': 0, 'max_features': 0.46221582597090677, 'max_depth': 5})
# (71.22657294396754, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 491, 'random_state': 0, 'max_features': 0.909651847972875, 'max_depth': 8})
# (70.819643596694505, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 279, 'random_state': 0, 'max_features': 0.1705562481728301, 'max_depth': 5})
# (69.953940300829728, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 833, 'random_state': 0, 'max_features': 0.7318062459649011, 'max_depth': 5})
# (80.345396821669567, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 806, 'random_state': 0, 'max_features': 0.8939903507280846, 'max_depth': 2})
# (77.325522665171121, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 559, 'random_state': 0, 'max_features': 0.0934492482954038, 'max_depth': 4})
# (72.112592957747069, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 7, 'random_state': 0, 'max_features': 0.7077690745047984, 'max_depth': 7})
# (73.423848416161334, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 325, 'random_state': 0, 'max_features': 0.09624258811912886, 'max_depth': 5})
# (70.194064901212712, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 268, 'random_state': 0, 'max_features': 0.7936918362029467, 'max_depth': 6})
# (99.65374122889699, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 566, 'random_state': 0, 'max_features': 0.40177254237223964, 'max_depth': 1})
# (71.484402582026206, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 134, 'random_state': 0, 'max_features': 0.08920792036183932, 'max_depth': 9})
# (78.992403096901427, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 635, 'random_state': 0, 'max_features': 0.8187249026171768, 'max_depth': 2})
# (70.065943152072776, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 355, 'random_state': 0, 'max_features': 0.7325898097726103, 'max_depth': 6})
# (91.631626640905537, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 424, 'random_state': 0, 'max_features': 0.016162704375026538, 'max_depth': 8})
# (69.734362231390463, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 369, 'random_state': 0, 'max_features': 0.6394163941460741, 'max_depth': 4})
# (81.109123602545978, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 319, 'random_state': 0, 'max_features': 0.9302260938171635, 'max_depth': 2})
# (70.515310653447315, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 343, 'random_state': 0, 'max_features': 0.41003012138581413, 'max_depth': 8})
# (70.627721840866442, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 768, 'random_state': 0, 'max_features': 0.18662446936067487, 'max_depth': 9})
# (70.932752515095856, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 458, 'random_state': 0, 'max_features': 0.36013511755527444, 'max_depth': 3})
# (71.571875372552952, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 186, 'random_state': 0, 'max_features': 0.18671424090783945, 'max_depth': 4})
# (82.528773904690695, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 859, 'random_state': 0, 'max_features': 0.21299051946004613, 'max_depth': 2})
# (73.269759187735318, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 703, 'random_state': 0, 'max_features': 0.09718562740925103, 'max_depth': 5})
# (71.506284071204448, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 146, 'random_state': 0, 'max_features': 0.06829004203629573, 'max_depth': 9})
# (70.751846483364389, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 214, 'random_state': 0, 'max_features': 0.6562170974823422, 'max_depth': 8})
# (70.75610383235005, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 867, 'random_state': 0, 'max_features': 0.7336571858443136, 'max_depth': 8})
# (73.530176607176358, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 37, 'random_state': 0, 'max_features': 0.07382531952959925, 'max_depth': 6})
# (80.802972088453629, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 169, 'random_state': 0, 'max_features': 0.25653373641417937, 'max_depth': 2})
# (81.376508787041857, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 398, 'random_state': 0, 'max_features': 0.9615097655058399, 'max_depth': 2})
# (70.140057636769697, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 849, 'random_state': 0, 'max_features': 0.7223583048271645, 'max_depth': 3})
# (70.371093964950674, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 381, 'random_state': 0, 'max_features': 0.29947374663150395, 'max_depth': 7})
# (69.983092410024085, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 134, 'random_state': 0, 'max_features': 0.3924180813939302, 'max_depth': 6})
# (70.234094870040238, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 234, 'random_state': 0, 'max_features': 0.6710582719331708, 'max_depth': 5})
# (70.114970468898605, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 820, 'random_state': 0, 'max_features': 0.6285071543114471, 'max_depth': 5})
# (79.657663965484645, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 585, 'random_state': 0, 'max_features': 0.28539578267590004, 'max_depth': 2})
# (73.707370062932753, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 876, 'random_state': 0, 'max_features': 0.8551158758704205, 'max_depth': 8})
# (78.762067168135545, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 261, 'random_state': 0, 'max_features': 0.8260081577297311, 'max_depth': 2})
# (113.8502838249867, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 714, 'random_state': 0, 'max_features': 0.11421761484022544, 'max_depth': 1})
# (69.959489058630282, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 368, 'random_state': 0, 'max_features': 0.7898350894540689, 'max_depth': 4})
# (121.99087400323572, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 891, 'random_state': 0, 'max_features': 0.067740007937325, 'max_depth': 1})
# (70.161742499022395, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 319, 'random_state': 0, 'max_features': 0.9942089579180077, 'max_depth': 3})
# (99.965229905968556, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 69, 'random_state': 0, 'max_features': 0.014534465865074554, 'max_depth': 6})
# (78.806440991132604, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 299, 'random_state': 0, 'max_features': 0.30875215915177134, 'max_depth': 2})
# (74.290105858808076, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 556, 'random_state': 0, 'max_features': 0.7668900655342828, 'max_depth': 9})
# (69.913973197941871, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 112, 'random_state': 0, 'max_features': 0.5649844993629758, 'max_depth': 6})
# (78.275107707161709, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 479, 'random_state': 0, 'max_features': 0.03509908001112663, 'max_depth': 8})
# (70.915828863767288, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 678, 'random_state': 0, 'max_features': 0.9951146441187324, 'max_depth': 7})
# (70.083866763159222, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 703, 'random_state': 0, 'max_features': 0.215538364812884, 'max_depth': 6})
# (71.80049626490019, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 309, 'random_state': 0, 'max_features': 0.3983201133074309, 'max_depth': 8})
# (79.644679104653747, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 37, 'random_state': 0, 'max_features': 0.8579712232903329, 'max_depth': 2})
# (76.492554851832494, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 374, 'random_state': 0, 'max_features': 0.598229832703282, 'max_depth': 2})
# (69.968443027024875, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 781, 'random_state': 0, 'max_features': 0.6817227372848627, 'max_depth': 5})
# (70.809209212849581, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 29, 'random_state': 0, 'max_features': 0.6920394431653122, 'max_depth': 8})
# (70.984615306603246, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 699, 'random_state': 0, 'max_features': 0.8119930546618931, 'max_depth': 8})
# (70.031337678826631, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 6, 'n_estimators': 209, 'random_state': 0, 'max_features': 0.5016292567620958, 'max_depth': 7})
# (70.388786657964204, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 725, 'random_state': 0, 'max_features': 0.7365181064814447, 'max_depth': 7})
# (70.253913087391666, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 435, 'random_state': 0, 'max_features': 0.7938546816724561, 'max_depth': 3})
# (70.841748887545293, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 235, 'random_state': 0, 'max_features': 0.2465599745657285, 'max_depth': 9})
# (70.42864879982497, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 4, 'n_estimators': 582, 'random_state': 0, 'max_features': 0.9430460899314257, 'max_depth': 3})
# (70.282496347186239, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 241, 'random_state': 0, 'max_features': 0.2595625407292646, 'max_depth': 4})
# (101.51050204184504, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 556, 'random_state': 0, 'max_features': 0.2779247056881444, 'max_depth': 1})
# (71.415157285062264, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 46, 'random_state': 0, 'max_features': 0.18129771068926967, 'max_depth': 4})
# (71.641063689721292, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 9, 'random_state': 0, 'max_features': 0.932414225487935, 'max_depth': 6})
# (71.084192749979266, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 1, 'n_estimators': 624, 'random_state': 0, 'max_features': 0.7376742383186478, 'max_depth': 6})
# (69.989599717037379, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 5, 'n_estimators': 836, 'random_state': 0, 'max_features': 0.3614879073530651, 'max_depth': 7})
# (69.986177290403077, 69.595872073691353, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 869, 'random_state': 0, 'max_features': 0.6889464385582046, 'max_depth': 6})
# (2548.2662904752201, 2548.2662904752201, {'num_parallel_tree': 2, 'subsample': 0.09425266620971025, 'seed': 0, 'colsample_bytree': 0.19609677835390207, 'nrounds': 609, 'objective': 'reg:linear', 'learning_rate': 0.0011713335517742837, 'max_depth': 6, 'min_child_weight': 4})
# (71.627042236095292, 71.627042236095292, {'num_parallel_tree': 1, 'subsample': 0.43667217824856197, 'seed': 0, 'colsample_bytree': 0.3355914860436462, 'nrounds': 594, 'objective': 'reg:linear', 'learning_rate': 0.054814786745614838, 'max_depth': 1, 'min_child_weight': 2})
# (72.926722263918037, 71.627042236095292, {'num_parallel_tree': 1, 'subsample': 0.3038511256387514, 'seed': 0, 'colsample_bytree': 0.23380123281159879, 'nrounds': 569, 'objective': 'reg:linear', 'learning_rate': 0.01512150217493992, 'max_depth': 9, 'min_child_weight': 1})
# (77.835664671632045, 71.627042236095292, {'num_parallel_tree': 2, 'subsample': 0.2524163405176291, 'seed': 0, 'colsample_bytree': 0.1895657242666976, 'nrounds': 576, 'objective': 'reg:linear', 'learning_rate': 0.048824269563816892, 'max_depth': 7, 'min_child_weight': 4})
# (264.60817063657072, 71.627042236095292, {'num_parallel_tree': 2, 'subsample': 0.13044541472390603, 'seed': 0, 'colsample_bytree': 0.4730411171118078, 'nrounds': 455, 'objective': 'reg:linear', 'learning_rate': 0.0044106895295583232, 'max_depth': 5, 'min_child_weight': 3})
# (72.693130688435204, 71.627042236095292, {'num_parallel_tree': 2, 'subsample': 0.09157016383703104, 'seed': 0, 'colsample_bytree': 0.6718422530959822, 'nrounds': 313, 'objective': 'reg:linear', 'learning_rate': 0.025943055224414063, 'max_depth': 3, 'min_child_weight': 2})
# (3111.2904998225454, 71.627042236095292, {'num_parallel_tree': 1, 'subsample': 0.04188623052169119, 'seed': 0, 'colsample_bytree': 0.8232438916316215, 'nrounds': 609, 'objective': 'reg:linear', 'learning_rate': 0.0010074390781661113, 'max_depth': 2, 'min_child_weight': 2})
# (723.86360939872759, 71.627042236095292, {'num_parallel_tree': 1, 'subsample': 0.5925119132569975, 'seed': 0, 'colsample_bytree': 0.30632639364760583, 'nrounds': 641, 'objective': 'reg:linear', 'learning_rate': 0.0021462875558142316, 'max_depth': 9, 'min_child_weight': 3})
# (246.79896435214746, 71.627042236095292, {'num_parallel_tree': 2, 'subsample': 0.660827977417876, 'seed': 0, 'colsample_bytree': 0.771630998990364, 'nrounds': 384, 'objective': 'reg:linear', 'learning_rate': 0.0052788071787060577, 'max_depth': 6, 'min_child_weight': 1})
# (2592.2709549217388, 71.627042236095292, {'num_parallel_tree': 2, 'subsample': 0.5960825437118108, 'seed': 0, 'colsample_bytree': 0.6859109551444921, 'nrounds': 346, 'objective': 'reg:linear', 'learning_rate': 0.0020141221623255299, 'max_depth': 2, 'min_child_weight': 2})
# (75.405243587176088, 71.627042236095292, {'num_parallel_tree': 1, 'subsample': 0.5860978032838219, 'seed': 0, 'colsample_bytree': 0.5537960936511985, 'nrounds': 734, 'objective': 'reg:linear', 'learning_rate': 0.0174956820486258, 'max_depth': 8, 'min_child_weight': 4})
# (70.112688493733884, 70.112688493733884, {'num_parallel_tree': 1, 'subsample': 0.6751813828852985, 'seed': 0, 'colsample_bytree': 0.6647755593216558, 'nrounds': 506, 'objective': 'reg:linear', 'learning_rate': 0.024016150671698377, 'max_depth': 3, 'min_child_weight': 3})
# (72.331709118721648, 70.112688493733884, {'num_parallel_tree': 2, 'subsample': 0.5724237061278397, 'seed': 0, 'colsample_bytree': 0.860576672009076, 'nrounds': 320, 'objective': 'reg:linear', 'learning_rate': 0.013996945589677609, 'max_depth': 9, 'min_child_weight': 4})
# (77.294097975651269, 70.112688493733884, {'num_parallel_tree': 2, 'subsample': 0.6152410237965557, 'seed': 0, 'colsample_bytree': 0.5638798075242324, 'nrounds': 368, 'objective': 'reg:linear', 'learning_rate': 0.058922539788473768, 'max_depth': 7, 'min_child_weight': 2})
# (71.609848870844246, 70.112688493733884, {'num_parallel_tree': 1, 'subsample': 0.1483356074421952, 'seed': 0, 'colsample_bytree': 0.7500358208899197, 'nrounds': 706, 'objective': 'reg:linear', 'learning_rate': 0.0071787103235223023, 'max_depth': 5, 'min_child_weight': 2})
# (71.112816175116251, 70.112688493733884, {'num_parallel_tree': 2, 'subsample': 0.326128681903363, 'seed': 0, 'colsample_bytree': 0.5446655881380735, 'nrounds': 425, 'objective': 'reg:linear', 'learning_rate': 0.014742778757562244, 'max_depth': 6, 'min_child_weight': 1})
# (69.224853263874834, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.8342073182948629, 'seed': 0, 'colsample_bytree': 0.9594869515208326, 'nrounds': 745, 'objective': 'reg:linear', 'learning_rate': 0.013712060877019244, 'max_depth': 2, 'min_child_weight': 1})
# (363.77709380606143, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.915604281563534, 'seed': 0, 'colsample_bytree': 0.29136238146147925, 'nrounds': 346, 'objective': 'reg:linear', 'learning_rate': 0.0051446271518285512, 'max_depth': 2, 'min_child_weight': 2})
# (88.637501836267049, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.4435045297691599, 'seed': 0, 'colsample_bytree': 0.4746530618921719, 'nrounds': 472, 'objective': 'reg:linear', 'learning_rate': 0.098484906287727561, 'max_depth': 8, 'min_child_weight': 1})
# (76.444211087151899, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.7313794218616742, 'seed': 0, 'colsample_bytree': 0.08416920419331932, 'nrounds': 792, 'objective': 'reg:linear', 'learning_rate': 0.082776296257084506, 'max_depth': 5, 'min_child_weight': 1})
# (79.592430145238325, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.853500550892511, 'seed': 0, 'colsample_bytree': 0.9322920066011224, 'nrounds': 740, 'objective': 'reg:linear', 'learning_rate': 0.028834226285148142, 'max_depth': 8, 'min_child_weight': 3})
# (80.763374603188566, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5102024041422133, 'seed': 0, 'colsample_bytree': 0.44217699901265217, 'nrounds': 627, 'objective': 'reg:linear', 'learning_rate': 0.061704285670408657, 'max_depth': 6, 'min_child_weight': 4})
# (1039.1599588434442, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5954579484412017, 'seed': 0, 'colsample_bytree': 0.6113452930975559, 'nrounds': 739, 'objective': 'reg:linear', 'learning_rate': 0.0016064708524770642, 'max_depth': 1, 'min_child_weight': 2})
# (118.73315621382358, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.024203898651638377, 'seed': 0, 'colsample_bytree': 0.6389835183787916, 'nrounds': 782, 'objective': 'reg:linear', 'learning_rate': 0.068628640154306739, 'max_depth': 8, 'min_child_weight': 2})
# (76.744281116101604, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.8692134737643565, 'seed': 0, 'colsample_bytree': 0.7179826673830736, 'nrounds': 568, 'objective': 'reg:linear', 'learning_rate': 0.068142363215276558, 'max_depth': 5, 'min_child_weight': 1})
# (71.186573783747093, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.5394424270601633, 'seed': 0, 'colsample_bytree': 0.4797335919938434, 'nrounds': 427, 'objective': 'reg:linear', 'learning_rate': 0.021864266718979373, 'max_depth': 5, 'min_child_weight': 1})
# (75.393727699451276, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.45820976413797293, 'seed': 0, 'colsample_bytree': 0.9206878983087929, 'nrounds': 544, 'objective': 'reg:linear', 'learning_rate': 0.034811119156907301, 'max_depth': 5, 'min_child_weight': 2})
# (71.213252159084419, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.1440539346247374, 'seed': 0, 'colsample_bytree': 0.30999071259423217, 'nrounds': 511, 'objective': 'reg:linear', 'learning_rate': 0.020233071993732261, 'max_depth': 2, 'min_child_weight': 2})
# (83.911551720389582, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.42706621564508634, 'seed': 0, 'colsample_bytree': 0.9295592370852787, 'nrounds': 581, 'objective': 'reg:linear', 'learning_rate': 0.074076085385296545, 'max_depth': 7, 'min_child_weight': 2})
# (75.654047358834589, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.3389876671755344, 'seed': 0, 'colsample_bytree': 0.23062647915410567, 'nrounds': 716, 'objective': 'reg:linear', 'learning_rate': 0.032043213264858081, 'max_depth': 5, 'min_child_weight': 1})
# (72.303644634860404, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.8061945877453738, 'seed': 0, 'colsample_bytree': 0.945598645122863, 'nrounds': 318, 'objective': 'reg:linear', 'learning_rate': 0.032651644355576721, 'max_depth': 1, 'min_child_weight': 3})
# (2623.2979489458453, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.395019026578596, 'seed': 0, 'colsample_bytree': 0.4483376879820575, 'nrounds': 334, 'objective': 'reg:linear', 'learning_rate': 0.0020702528943088243, 'max_depth': 9, 'min_child_weight': 1})
# (70.91466126458478, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.5750645060928262, 'seed': 0, 'colsample_bytree': 0.35802716110727617, 'nrounds': 522, 'objective': 'reg:linear', 'learning_rate': 0.072802637995980829, 'max_depth': 2, 'min_child_weight': 2})
# (2966.1489375748483, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.519590575665524, 'seed': 0, 'colsample_bytree': 0.27680881389778694, 'nrounds': 570, 'objective': 'reg:linear', 'learning_rate': 0.0011069074759321245, 'max_depth': 1, 'min_child_weight': 2})
# (330.50070996898222, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.1421593061451609, 'seed': 0, 'colsample_bytree': 0.22606223378177098, 'nrounds': 624, 'objective': 'reg:linear', 'learning_rate': 0.0029851892751593771, 'max_depth': 8, 'min_child_weight': 3})
# (653.56882892003432, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.8749651057298463, 'seed': 0, 'colsample_bytree': 0.9354533345178855, 'nrounds': 492, 'objective': 'reg:linear', 'learning_rate': 0.0029019157164143642, 'max_depth': 3, 'min_child_weight': 1})
# (178.02353343177265, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.052710263938945685, 'seed': 0, 'colsample_bytree': 0.435024937593089, 'nrounds': 440, 'objective': 'reg:linear', 'learning_rate': 0.0053621331959625594, 'max_depth': 6, 'min_child_weight': 4})
# (71.887999672241278, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.3974110777364013, 'seed': 0, 'colsample_bytree': 0.5102245224619892, 'nrounds': 731, 'objective': 'reg:linear', 'learning_rate': 0.02524982668376724, 'max_depth': 3, 'min_child_weight': 1})
# (3823.9401789904991, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.5862624880365054, 'seed': 0, 'colsample_bytree': 0.27364895834845115, 'nrounds': 310, 'objective': 'reg:linear', 'learning_rate': 0.0016066296847178773, 'max_depth': 5, 'min_child_weight': 4})
# (1058.4948645688776, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.10385516498886381, 'seed': 0, 'colsample_bytree': 0.19520339881523183, 'nrounds': 613, 'objective': 'reg:linear', 'learning_rate': 0.001927476215348339, 'max_depth': 9, 'min_child_weight': 3})
# (136.75384348087894, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.28289870681185414, 'seed': 0, 'colsample_bytree': 0.2031602980793779, 'nrounds': 721, 'objective': 'reg:linear', 'learning_rate': 0.0035469338784821008, 'max_depth': 4, 'min_child_weight': 4})
# (206.82693838679583, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.3587385795393741, 'seed': 0, 'colsample_bytree': 0.43838002188234493, 'nrounds': 402, 'objective': 'reg:linear', 'learning_rate': 0.0053803271807428762, 'max_depth': 4, 'min_child_weight': 3})
# (83.085658374485675, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.844637748756506, 'seed': 0, 'colsample_bytree': 0.635873803764393, 'nrounds': 373, 'objective': 'reg:linear', 'learning_rate': 0.008836151174975387, 'max_depth': 3, 'min_child_weight': 1})
# (71.091385596714687, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6856085093215589, 'seed': 0, 'colsample_bytree': 0.6638275325846428, 'nrounds': 768, 'objective': 'reg:linear', 'learning_rate': 0.074397697197664425, 'max_depth': 1, 'min_child_weight': 3})
# (73.025313402284752, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.8971449515593687, 'seed': 0, 'colsample_bytree': 0.06351238009945967, 'nrounds': 521, 'objective': 'reg:linear', 'learning_rate': 0.077463240563016011, 'max_depth': 4, 'min_child_weight': 3})
# (1003.588129876933, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.3785700179545626, 'seed': 0, 'colsample_bytree': 0.5771577104871213, 'nrounds': 524, 'objective': 'reg:linear', 'learning_rate': 0.0022828251013212999, 'max_depth': 4, 'min_child_weight': 3})
# (90.20519478110279, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.11736629291096116, 'seed': 0, 'colsample_bytree': 0.452711826529041, 'nrounds': 525, 'objective': 'reg:linear', 'learning_rate': 0.064826313462553062, 'max_depth': 7, 'min_child_weight': 1})
# (90.974547165523475, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.7484862897450288, 'seed': 0, 'colsample_bytree': 0.4649778736257355, 'nrounds': 300, 'objective': 'reg:linear', 'learning_rate': 0.010301706671053762, 'max_depth': 6, 'min_child_weight': 3})
# (74.718862498166843, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.9796566864735005, 'seed': 0, 'colsample_bytree': 0.5168333392539672, 'nrounds': 436, 'objective': 'reg:linear', 'learning_rate': 0.008785882378081528, 'max_depth': 2, 'min_child_weight': 3})
# (75.870760318917817, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.21982330774200504, 'seed': 0, 'colsample_bytree': 0.44169079636796404, 'nrounds': 768, 'objective': 'reg:linear', 'learning_rate': 0.018701410343825418, 'max_depth': 9, 'min_child_weight': 4})
# (73.757480433113685, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.08185212547482759, 'seed': 0, 'colsample_bytree': 0.08334809841353018, 'nrounds': 785, 'objective': 'reg:linear', 'learning_rate': 0.036080348499192186, 'max_depth': 2, 'min_child_weight': 2})
# (2858.3154706028863, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.4621639131641812, 'seed': 0, 'colsample_bytree': 0.7843779695114331, 'nrounds': 365, 'objective': 'reg:linear', 'learning_rate': 0.0017711926402405067, 'max_depth': 8, 'min_child_weight': 2})
# (72.07780866144175, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.4226513377356907, 'seed': 0, 'colsample_bytree': 0.6465442280516077, 'nrounds': 688, 'objective': 'reg:linear', 'learning_rate': 0.0061558969156493568, 'max_depth': 5, 'min_child_weight': 2})
# (73.951235368045715, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.450065031748913, 'seed': 0, 'colsample_bytree': 0.36591090390888237, 'nrounds': 779, 'objective': 'reg:linear', 'learning_rate': 0.034566370301994234, 'max_depth': 4, 'min_child_weight': 1})
# (81.741484268531195, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.24006551517704386, 'seed': 0, 'colsample_bytree': 0.5298281441280145, 'nrounds': 552, 'objective': 'reg:linear', 'learning_rate': 0.064937684647498398, 'max_depth': 5, 'min_child_weight': 4})
# (263.09757643987206, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.6030978379970307, 'seed': 0, 'colsample_bytree': 0.796905723925707, 'nrounds': 461, 'objective': 'reg:linear', 'learning_rate': 0.0043089938273472702, 'max_depth': 8, 'min_child_weight': 1})
# (72.027776788646506, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.10095256527540299, 'seed': 0, 'colsample_bytree': 0.8658518153107206, 'nrounds': 636, 'objective': 'reg:linear', 'learning_rate': 0.0078289492456701214, 'max_depth': 4, 'min_child_weight': 1})
# (5117.3853174666301, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.09403264632729674, 'seed': 0, 'colsample_bytree': 0.3252713765956953, 'nrounds': 318, 'objective': 'reg:linear', 'learning_rate': 0.0011066110279948473, 'max_depth': 3, 'min_child_weight': 4})
# (282.45963338124551, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.1705492027204579, 'seed': 0, 'colsample_bytree': 0.6253363309647131, 'nrounds': 547, 'objective': 'reg:linear', 'learning_rate': 0.0035781798103515336, 'max_depth': 9, 'min_child_weight': 3})
# (71.413271517816128, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.44229722931998805, 'seed': 0, 'colsample_bytree': 0.20749161632522242, 'nrounds': 648, 'objective': 'reg:linear', 'learning_rate': 0.0089190319628102595, 'max_depth': 7, 'min_child_weight': 2})
# (83.632042925426646, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.022530181960517544, 'seed': 0, 'colsample_bytree': 0.45396968918815345, 'nrounds': 708, 'objective': 'reg:linear', 'learning_rate': 0.079751905135922785, 'max_depth': 1, 'min_child_weight': 4})
# (69.917092929800745, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.5426628546977265, 'seed': 0, 'colsample_bytree': 0.25012763530126764, 'nrounds': 329, 'objective': 'reg:linear', 'learning_rate': 0.021756180789593384, 'max_depth': 4, 'min_child_weight': 1})
# (70.551471498227556, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.46991153318148443, 'seed': 0, 'colsample_bytree': 0.870425811988581, 'nrounds': 368, 'objective': 'reg:linear', 'learning_rate': 0.012606014117955115, 'max_depth': 4, 'min_child_weight': 2})
# (75.119065560794539, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.9391970014754327, 'seed': 0, 'colsample_bytree': 0.051649622191460624, 'nrounds': 577, 'objective': 'reg:linear', 'learning_rate': 0.069398196398106626, 'max_depth': 6, 'min_child_weight': 4})
# (69.958845916405068, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.8549916899732929, 'seed': 0, 'colsample_bytree': 0.9315133446123475, 'nrounds': 401, 'objective': 'reg:linear', 'learning_rate': 0.060211549854071546, 'max_depth': 2, 'min_child_weight': 4})
# (1180.423820551938, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.0725802009397946, 'seed': 0, 'colsample_bytree': 0.8413098736050746, 'nrounds': 419, 'objective': 'reg:linear', 'learning_rate': 0.0026766635249636682, 'max_depth': 8, 'min_child_weight': 2})
# (72.513016064389205, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.47855676187741625, 'seed': 0, 'colsample_bytree': 0.747865018883074, 'nrounds': 494, 'objective': 'reg:linear', 'learning_rate': 0.014394542605864218, 'max_depth': 8, 'min_child_weight': 4})
# (96.785157663391317, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.5997873337496215, 'seed': 0, 'colsample_bytree': 0.6118947145949472, 'nrounds': 764, 'objective': 'reg:linear', 'learning_rate': 0.0039125127056876142, 'max_depth': 2, 'min_child_weight': 1})
# (81.295651200488393, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.7275973576485633, 'seed': 0, 'colsample_bytree': 0.48104246078307245, 'nrounds': 550, 'objective': 'reg:linear', 'learning_rate': 0.061815977541111303, 'max_depth': 8, 'min_child_weight': 2})
# (4661.2315760886813, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6080621792864677, 'seed': 0, 'colsample_bytree': 0.44713494238207374, 'nrounds': 320, 'objective': 'reg:linear', 'learning_rate': 0.0012391517546613724, 'max_depth': 7, 'min_child_weight': 2})
# (80.951910748843829, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.3129873713680909, 'seed': 0, 'colsample_bytree': 0.45750643241248146, 'nrounds': 327, 'objective': 'reg:linear', 'learning_rate': 0.060408056732846556, 'max_depth': 9, 'min_child_weight': 1})
# (2364.8902036722498, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.44767976564019474, 'seed': 0, 'colsample_bytree': 0.49352041268582447, 'nrounds': 667, 'objective': 'reg:linear', 'learning_rate': 0.0011166706068141852, 'max_depth': 8, 'min_child_weight': 2})
# (73.760440833827587, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.2991930767509107, 'seed': 0, 'colsample_bytree': 0.3085074059874727, 'nrounds': 681, 'objective': 'reg:linear', 'learning_rate': 0.029401248044470588, 'max_depth': 4, 'min_child_weight': 1})
# (1067.0253369235022, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.8364826444524995, 'seed': 0, 'colsample_bytree': 0.3473443812369843, 'nrounds': 388, 'objective': 'reg:linear', 'learning_rate': 0.0029938982822059006, 'max_depth': 7, 'min_child_weight': 1})
# (74.827918360426608, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.12443283324578304, 'seed': 0, 'colsample_bytree': 0.034968950884361055, 'nrounds': 425, 'objective': 'reg:linear', 'learning_rate': 0.059629534623102505, 'max_depth': 1, 'min_child_weight': 4})
# (76.009406119451285, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.7720002875147913, 'seed': 0, 'colsample_bytree': 0.8960076147159891, 'nrounds': 405, 'objective': 'reg:linear', 'learning_rate': 0.032450685231735339, 'max_depth': 8, 'min_child_weight': 4})
# (1975.8318168713258, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6147566534815881, 'seed': 0, 'colsample_bytree': 0.15992606700655865, 'nrounds': 767, 'objective': 'reg:linear', 'learning_rate': 0.0011007504267346291, 'max_depth': 1, 'min_child_weight': 2})
# (69.500763401342567, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6852156768216082, 'seed': 0, 'colsample_bytree': 0.9103394950561767, 'nrounds': 568, 'objective': 'reg:linear', 'learning_rate': 0.023182333155226695, 'max_depth': 2, 'min_child_weight': 1})
# (77.393842733606178, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6924256727555228, 'seed': 0, 'colsample_bytree': 0.1435366506852941, 'nrounds': 494, 'objective': 'reg:linear', 'learning_rate': 0.050640101129114129, 'max_depth': 8, 'min_child_weight': 4})
# (71.674702200067912, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.14652088471648528, 'seed': 0, 'colsample_bytree': 0.13755930347563, 'nrounds': 759, 'objective': 'reg:linear', 'learning_rate': 0.02224232691692473, 'max_depth': 2, 'min_child_weight': 3})
# (87.342998218242045, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.3438146693385423, 'seed': 0, 'colsample_bytree': 0.42446972809226935, 'nrounds': 689, 'objective': 'reg:linear', 'learning_rate': 0.0046742131556914762, 'max_depth': 5, 'min_child_weight': 2})
# (83.874235104396803, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.6136472217436033, 'seed': 0, 'colsample_bytree': 0.7787312131819805, 'nrounds': 639, 'objective': 'reg:linear', 'learning_rate': 0.062248328825855501, 'max_depth': 9, 'min_child_weight': 3})
# (74.536097692745287, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.7164883778480555, 'seed': 0, 'colsample_bytree': 0.061307015681358365, 'nrounds': 487, 'objective': 'reg:linear', 'learning_rate': 0.012681227522114898, 'max_depth': 7, 'min_child_weight': 4})
# (71.506953288766169, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.845642097548869, 'seed': 0, 'colsample_bytree': 0.4377848894456991, 'nrounds': 606, 'objective': 'reg:linear', 'learning_rate': 0.027759575136122865, 'max_depth': 4, 'min_child_weight': 4})
# (83.722967189078588, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6992668604032086, 'seed': 0, 'colsample_bytree': 0.4288523687605514, 'nrounds': 728, 'objective': 'reg:linear', 'learning_rate': 0.065565359326526407, 'max_depth': 8, 'min_child_weight': 2})
# (588.7942312229053, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.2171052213329921, 'seed': 0, 'colsample_bytree': 0.6514432766387533, 'nrounds': 788, 'objective': 'reg:linear', 'learning_rate': 0.0018992392867267262, 'max_depth': 8, 'min_child_weight': 2})
# (2896.4956694852767, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.7357636285141639, 'seed': 0, 'colsample_bytree': 0.8943817139601324, 'nrounds': 476, 'objective': 'reg:linear', 'learning_rate': 0.001342359158124507, 'max_depth': 4, 'min_child_weight': 3})
# (84.724772917263863, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.2164333490156667, 'seed': 0, 'colsample_bytree': 0.41049042380919815, 'nrounds': 706, 'objective': 'reg:linear', 'learning_rate': 0.005487837247510759, 'max_depth': 1, 'min_child_weight': 3})
# (71.199858273834963, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5947875419201621, 'seed': 0, 'colsample_bytree': 0.23743575521685512, 'nrounds': 384, 'objective': 'reg:linear', 'learning_rate': 0.016290457930333315, 'max_depth': 6, 'min_child_weight': 2})
# (72.153740565722629, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.6948837585195627, 'seed': 0, 'colsample_bytree': 0.6668523715399053, 'nrounds': 624, 'objective': 'reg:linear', 'learning_rate': 0.011257189208907422, 'max_depth': 8, 'min_child_weight': 3})
# (136.82267148782117, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.7975774127911915, 'seed': 0, 'colsample_bytree': 0.44213619907892254, 'nrounds': 723, 'objective': 'reg:linear', 'learning_rate': 0.0034809869548798316, 'max_depth': 5, 'min_child_weight': 1})
# (71.962434621039989, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5987454233404388, 'seed': 0, 'colsample_bytree': 0.7711551908118616, 'nrounds': 415, 'objective': 'reg:linear', 'learning_rate': 0.013383410506581652, 'max_depth': 8, 'min_child_weight': 2})
# (70.977246695959195, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.45092751174034856, 'seed': 0, 'colsample_bytree': 0.9606977574907714, 'nrounds': 623, 'objective': 'reg:linear', 'learning_rate': 0.04123433883761448, 'max_depth': 2, 'min_child_weight': 4})
# (1622.1759446130065, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5879752176018674, 'seed': 0, 'colsample_bytree': 0.8640863075694489, 'nrounds': 567, 'objective': 'reg:linear', 'learning_rate': 0.0016570066258061048, 'max_depth': 9, 'min_child_weight': 3})
# (75.72257471773716, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.24873703356624097, 'seed': 0, 'colsample_bytree': 0.6643896160883468, 'nrounds': 443, 'objective': 'reg:linear', 'learning_rate': 0.012890324810952881, 'max_depth': 1, 'min_child_weight': 4})
# (4845.6883143305722, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.4862462547998997, 'seed': 0, 'colsample_bytree': 0.3629873805808216, 'nrounds': 347, 'objective': 'reg:linear', 'learning_rate': 0.0010869421216121423, 'max_depth': 5, 'min_child_weight': 1})
# (2147.8574991813775, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.42767922262580055, 'seed': 0, 'colsample_bytree': 0.7888948097520987, 'nrounds': 651, 'objective': 'reg:linear', 'learning_rate': 0.001220301576766713, 'max_depth': 7, 'min_child_weight': 4})
# (526.93656789947067, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.4089595458800245, 'seed': 0, 'colsample_bytree': 0.15242363781529567, 'nrounds': 552, 'objective': 'reg:linear', 'learning_rate': 0.00284399055298006, 'max_depth': 2, 'min_child_weight': 1})
# (1024.547421899447, 69.224853263874834, {'num_parallel_tree': 1, 'subsample': 0.5107617399771468, 'seed': 0, 'colsample_bytree': 0.463941284840473, 'nrounds': 775, 'objective': 'reg:linear', 'learning_rate': 0.0015424111706602128, 'max_depth': 1, 'min_child_weight': 2})
# (85.204269058378713, 69.224853263874834, {'num_parallel_tree': 2, 'subsample': 0.13117771611214774, 'seed': 0, 'colsample_bytree': 0.39123669298673236, 'nrounds': 594, 'objective': 'reg:linear', 'learning_rate': 0.053930309498667915, 'max_depth': 8, 'min_child_weight': 1})

# %% [markdown]
# # Second Layer

# %%
xgb_data = pickle.load(open('xgb.p','rb'))
et_data = pickle.load(open('et.p','rb'))
rf_data = pickle.load(open('rf.p','rb'))
L = 30
N = 3
X_val_bar = np.zeros([4209, L*N])
X_test_bar = np.zeros([4209, L*N])
id_col = (i for i in range(L*N)) 
for dt in sorted(et_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])

for dt in sorted(rf_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])
for dt in sorted(xgb_data, key =  lambda x: x[1])[:L]:
    j = next(id_col)
    X_val_bar[:,j] = np.squeeze(dt[3])
    X_test_bar[:,j] = np.squeeze(dt[4])

# %%
def get_oof_2nd_layer(clf,X_train,y_train, X_val):
    ntrain = X_train.shape[0]
    nval = X_val.shape[0]
    oof_train = np.zeros((ntrain,))
    oof_val = np.zeros((nval,))
    oof_val_skf = np.empty((NFOLDS, nval))
    kf = KFold(ntrain, n_folds=NFOLDS, shuffle=True, random_state=SEED)
    for i, (train_index, test_index) in enumerate(kf):
        X_tr = X_train[train_index]
        y_tr = y_train[train_index]
        X_te = X_train[test_index]
        clf.train(X_tr, y_tr)
        oof_train[test_index] = clf.predict(X_te)
        oof_val_skf[i, :] = clf.predict(X_val)
    oof_val[:] = oof_val_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_val.reshape(-1, 1)

def turing_2nd_layer(clf,N):
    best_err = 100000000
    data = []
    for _ in range(N):
        n_estimators = int(np.random.uniform(1,900))
        max_features = np.random.uniform(0.01,1)
        max_depth = int(np.random.uniform(1,10))
        min_samples_leaf = int(np.random.uniform(1,7))
        params = {
            'n_jobs': 8,
            'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_samples_leaf': min_samples_leaf,
        }
        model = SklearnWrapper(clf=clf, seed=SEED, params=params)
        oof_val, oof_test = get_oof_2nd_layer(model, X_val_bar, y_val, X_test_bar)
        err = mean_squared_error(y_val, oof_val)
        if best_err > err:
            best_err = err
            best_para = params
            best_y = oof_test
        print(err,best_err, params)
    #pickle.dump(best_para,open("2nd_layer_para.p",'wb'))
    return best_y

# %%
best_y = turing_2nd_layer(RandomForestRegressor, 40)
# Out:
# (71.687981924111781, 71.687981924111781, {'n_jobs': 8, 'min_samples_leaf': 2, 'n_estimators': 704, 'random_state': 0, 'max_features': 0.43348940182567225, 'max_depth': 1})
# (71.695845888564932, 71.687981924111781, {'n_jobs': 8, 'min_samples_leaf': 3, 'n_estimators': 531, 'random_state': 0, 'max_features': 0.39009745922801164, 'max_depth': 1})

# %%
submission = pd.read_csv(SUBMISSION_FILE)
submission.iloc[:, 1] = best_y
submission.to_csv('stacking_sub.csv', index=None)
